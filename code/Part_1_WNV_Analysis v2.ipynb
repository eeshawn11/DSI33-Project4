# %% [markdown]
# # West Nile Virus Analysis & Prediction

# %% [markdown]
# # Part 1

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# In 2022, Chicago reported one human case of West Nile virus (WNV) towards the end of the summer and early fall season. This is remarkable compared to the previous 13 reported cases in the previous year, and even more in the years before.
#
# WNV is the leading cause of mosquito-borne disease in the US, and it is spread to people by the bite of an infected mosquito, specifically a Culex pipiens mosquito. One in five infected people with WNV would experience fever, nausea, headache and muscle aches lasting from a few days to a few weeks - while the remaining four out of five would not exhibit any symptoms. However the virus remains a major concern as individuals with weaker immune systems and those above 60 are at higher risk for severe illness from WNV.
#
# Every year the Chicago Department of Public Health (CDPH) runs a comprehensive surveillance program in suburban areas to trap mosquitoes and test them for WNV. This data has helped CDPH target high-risk areas for the virus and significantly reduce the number of positive cases in the last few years. ([source](https://www.chicago.gov/city/en/depts/cdph/provdrs/healthy_communities/news/2022/september/first-human-case-of-west-nile-virus-detected-in-chicago-in-2022.html))
#
# However the CDPH recognized that the last few years of data have major anomalies due to the COVID-19 pandemic and low infection count, hence we may not be able to use recent data to create an action plan for 2023. Our team at the Disease and Treatment Agency was tasked to analyze the years with more severe WNV outbreak and devise a plan to minimize the spread of the WNV. Through the historical data from the WNV surveillance reports coupled with weather information and pesticide usage,
# 1. We used machine learning models to predict when and where the mosquitoes will test positive for WNV.
# 2. The best model allowed us to predict WNV outbreaks as accurately as possible so that we can effectively allocate resources to curb the virus transmission.

# %% [markdown]
# *Content:*
#
# 1. [Executive Summary](#Executive-Summary)
# 2. [Datasets & Methodology](#Datasets-&-Methodology)
# 3. [Data Cleaning](#Data-Cleaning)
# 4. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# 5. [Feature Engineering](#Feature-Engineering)
#
# *Links to next notebooks:*
# - Part 2: Modeling & Tuning
# - Part 3: Conclusion & Recommendations

# %% [markdown]
# ## Datasets & Methodology

# %% [markdown]
# ### About the datasets
#
# - [`train.csv`](../assets/train.csv): This is the main dataset we'll be working with, which contains 10,506 observations on the presence of West Nile Virus across neighborhood clusters in Chicago, Illinois. This dataset is taken from the years 2007, 2009, 2011 and 2013. There are a total of 11 variables involved in tracking the West Nile Virus in the neighborhoods.
# - [`test.csv`](../assets/test.csv): There's a total of 11 features and 116,293 observations for the years 2008, 2010, 2012 and 2014. The presence of West Nile Virus is missing from this set, which we will use our model to predict.
# - [`spray.csv`](../assets/spray.csv): This dataset contains 14,835 geographic information system (GIS) data on the city's spraying efforts in 2011 and 2013 - including the date, time, latitude and longitude.
# -  [`weather.csv`](../assets/weather.csv): This dataset contains weather information from 2007 to 2014 - covering 2,944 observations across 22 relevant weather-related variables.
# - [`mapdata_copyright_openstreetmap_contributors.txt`](../assets/mapdata_copyright_openstreetmap_contributors.txt): Map files from Open Streetmap and used for visualizations in the analysis.

# %% [markdown]
# ### Data dictionary
#
# | **Feature**            	| **Type** 	| **Dataset**              	| **Description**                                                                         	|
# |------------------------	|----------	|--------------------------	|-----------------------------------------------------------------------------------------	|
# | Id                     	| int      	| `train.csv` & `test.csv` 	| ID number of the record                                                                 	|
# | Date                   	| object   	| `train.csv` & `test.csv` 	| Refers to the date the West Nile Virus test is performed                                	|
# | Address                	| object   	| `train.csv` & `test.csv` 	| The approximate address of the location of trap; sent to GeoCoder                       	|
# | Species                	| object   	| `train.csv` & `test.csv` 	| The mosquito species in trap                                                            	|
# | Block                  	| int      	| `train.csv` & `test.csv` 	| Refers to block number of address                                                       	|
# | Street                 	| object   	| `train.csv` & `test.csv` 	| Refers to street of address                                                             	|
# | Trap                   	| object   	| `train.csv` & `test.csv` 	| ID number of the trap                                                                   	|
# | AddressNumberAndStreet 	| object   	| `train.csv` & `test.csv` 	| The approximate address retrieved from GeoCoder                                         	|
# | Latitude               	| float    	| `train.csv` & `test.csv` 	| The latitude retrieved from GeoCoder                                                    	|
# | Longitude              	| float    	| `train.csv` & `test.csv` 	| The longitude retrieved from GeoCoder                                                   	|
# | AddressAccuracy        	| int      	| `train.csv` & `test.csv` 	| The accuracy of information returned from GeoCoder                                      	|
# | NumMosquitos           	| int      	| `train.csv` & `test.csv` 	| The number of mosquitoes in the trap                                                    	|
# | WnvPresent             	| int      	| `train.csv` & `test.csv` 	| Whether or not West Nile Virus is present in these mosquitoes (1 = present; 0 = absent) 	|
# | Date                   	| object   	| `spray.csv`              	| The date of spray                                                                       	|
# | Time                   	| object   	| `spray.csv`              	| The time of spray                                                                       	|
# | Latitude               	| float    	| `spray.csv`              	| Latitude of spray                                                                       	|
# | Longitude              	| float    	| `spray.csv`              	| Longitude of spray                                                                      	|
# | Station                	| int      	| `weather.csv`            	| Refers to the weather station (1 or 2)                                                  	|
# | Date                   	| object   	| `weather.csv`            	| Refers to the date of measurement                                                       	|
# | Tmax                   	| int      	| `weather.csv`            	| Maximum daily temperature (Degrees Fahrenheit)                                          	|
# | Tmin                   	| int      	| `weather.csv`            	| Minimum daily temperature (Degrees Fahrenheit)                                          	|
# | Tavg                   	| object   	| `weather.csv`            	| Average daily temperature (Degrees Fahrenheit)                                          	|
# | Depart                 	| object   	| `weather.csv`            	| Departure from normal temperature (Degrees Fahrenheit)                                  	|
# | Dewpoint               	| int      	| `weather.csv`            	| Average dew point (Degrees Fahrenheit)                                                  	|
# | WetBulb                	| object   	| `weather.csv`            	| Average wet bulb (Degrees Fahrenheit)                                                   	|
# | Heat                   	| object   	| `weather.csv`            	| Heating degree days                                                                     	|
# | Cool                   	| object   	| `weather.csv`            	| Cooling degree days                                                                     	|
# | Sunrise                	| object   	| `weather.csv`            	| Time of sunrise (calculated, not observed)                                              	|
# | Sunset                 	| object   	| `weather.csv`            	| Time of sunset (calculated, not observed)                                               	|
# | CodeSum                	| object   	| `weather.csv`            	| Code of weather phenomena                                                               	|
# | Depth                  	| object   	| `weather.csv`            	| Depth of snow on the ground (M = Missing data)                                          	|
# | Water1                 	| object   	| `weather.csv`            	| Water equivalent (M = Missing data)                                                     	|
# | SnowFall               	| object   	| `weather.csv`            	| Snowfall (inch) (M = Missing data, T= Trace)                                            	|
# | PrecipTotal            	| object   	| `weather.csv`            	| Total daily rainfall (inch)                                                             	|
# | StnPressure            	| object   	| `weather.csv`            	| Average atmospheric pressure (inch Hg)                                                  	|
# | SeaLevel               	| object   	| `weather.csv`            	| Average sea level pressure (inch Hg)                                                    	|
# | ResultSpeed            	| float    	| `weather.csv`            	| Resultant wind speed (mph)                                                              	|
# | ResultDir              	| int      	| `weather.csv`            	| Resultant wind direction (Degrees)                                                      	|
# | AvgSpeed               	| object   	| `weather.csv`            	| Average wind speed (mph)                                                                	|

# %% [markdown]
# ### Additional References

# %% [markdown]
# 1. [First Human Case of West Nile Virus Detected in Chicago in 2022](https://www.chicago.gov/city/en/depts/cdph/provdrs/healthy_communities/news/2022/september/first-human-case-of-west-nile-virus-detected-in-chicago-in-2022.html)
# - We referred to this news article on the most recent WNV report in 2022, along with summary of cases in 2021 and the virus.
# - The article helped us better understand context of WNV in Chicago and snippets from the article was included in the executive summary above.
#
# 2. [The drivers of West Nile virus human illness in the Chicago, Illinois, USA area](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7241786/)
# - We referred to this study to better understand how to assess factors influencing the WNV spread in Chicago.
#
# 3. [Mosquito Surveillance Software](https://www.cdc.gov/westnile/resourcepages/mosqSurvSoft.html)
# - We referred to this CDC guide on calculating virus infection rate, and attempted to include the calculation in the EDA process.
#
# 4. [Economic Cost Analysis of West Nile Virus Outbreak, Sacramento County, California, USA, 2005](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3322011/)
# - We referred to this study for an indication of economic costs involved in managing WNV outbreak.
# - The values from this study were used in the cost-benefit analysis section of our project.

# %% [markdown]
# ### Methodology
#
# For this project, we've conducted a thorough analysis and modeling through these steps:
# 1. **Data Cleaning**: We assessed the training dataset for any outliers and removed them immediately. We also checked for missing values where we've filled them or removed them if irrelevant.
# 2. **Exploratory Data Analysis**: We visualized the dataset through a series of graphs and plots to better understand the relationships between variables as well as its individual impact the spread of the West Nile Virus.
# 3. **Feature Engineering & Data Preprocessing**: After evaluating specific variables, we removed variables that didn't have much impact and combined variables that were relevant to each other.
# 4. **Data Modeling & Evaluation**: Based on the selected features, we modeled them through these classification models - **XXX**. The best model will then be used to predict the presence of West Nile Virus in the test dataset.
# 5. **Cost-Benefit Analysis**: Following the best model selected, we also conducted a cost-benefit analysis on annual cost of pesticide coverage and its benefits - particularly for areas that are at higher risk.
#
# We've also uploaded the predicted West Nile Virus presence on [Kaggle](https://www.kaggle.com/competitions/predict-west-nile-virus/data) to measure the accuracy of our finalized model.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import math
from datetime import datetime, time

from sklearn.impute import KNNImputer

#Ignore warnings
import warnings
warnings.filterwarnings("ignore")

#change display options
pd.set_option("display.max_rows", 160)
pd.set_option("display.max_columns", 80)
sns.set_theme(style="ticks", palette="flare")

# %% [markdown]
# ### Load datasets

# %%
df_train = pd.read_csv('../assets/train.csv')
df_spray = pd.read_csv('../assets/spray.csv')
df_weather = pd.read_csv('../assets/weather.csv')
map_data = np.loadtxt('../assets/mapdata_copyright_openstreetmap_contributors.txt')
df_test = pd.read_csv('../assets/test.csv')

# %% [markdown]
# ### Dataset: `train.csv`

# %%
df_train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    10506 non-null  object
#  1   Address                 10506 non-null  object
#  2   Species                 10506 non-null  object
#  3   Block                   10506 non-null  int64
#  4   Street                  10506 non-null  object
#  5   Trap                    10506 non-null  object
#  6   AddressNumberAndStreet  10506 non-null  object
#  7   Latitude                10506 non-null  float64
#  8   Longitude               10506 non-null  float64
#  9   AddressAccuracy         10506 non-null  int64
#  10  NumMosquitos            10506 non-null  int64
#  11  WnvPresent              10506 non-null  int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 985.1+ KB

# %%
df_train.isnull().sum()
# Out:
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64

# %%
# converting Date in train dataset to python readable date-time format
df_train['Date'] = pd.to_datetime(df_train['Date'])

# %%
# Date range:
print(f'From:{df_train["Date"].min()}')
print(f"To:{df_train['Date'].max()}")
# Out:
# From:2007-05-29 00:00:00
# To:2013-09-26 00:00:00

# %%
# extract the date features
df_train['Year'] = df_train['Date'].apply(lambda x: x.year)
df_train['Month'] = df_train['Date'].apply(lambda x: x.month)
df_train['Week'] = df_train['Date'].apply(lambda x: x.week)
df_train['DayOfWeek'] = df_train['Date'].apply(lambda x: x.dayofweek)

# %% [markdown]
# ### Dataset: `spray.csv`

# %% [markdown]
# The City of Chicago also does spraying to kill mosquitos. You are given the GIS data for their spray efforts in 2011 and 2013. Spraying can reduce the number of mosquitos in the area, and therefore might eliminate the appearance of West Nile virus.

# %%
df_spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
df_spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14835 non-null  object
#  1   Time       14251 non-null  object
#  2   Latitude   14835 non-null  float64
#  3   Longitude  14835 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 463.7+ KB

# %%
df_spray.isnull().sum()
# Out:
# Date           0
# Time         584
# Latitude       0
# Longitude      0
# dtype: int64

# %%
df_spray.head(10)
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858
# 5  2011-08-29  6:57:48 PM  42.390395 -88.088315
# 6  2011-08-29  6:57:58 PM  42.390673 -88.088002
# 7  2011-08-29  6:58:08 PM  42.391027 -88.088002
# 8  2011-08-29  6:58:18 PM  42.391403 -88.088003
# 9  2011-08-29  6:58:28 PM  42.391718 -88.087995

# %%
# Check that null values from Time column only occurs for 2011-09-07
df_spray[df_spray["Time"].isnull()].groupby("Date").Latitude.count()
# Out:
# Date
# 2011-09-07    584
# Name: Latitude, dtype: int64

# %%
# Mode/Median for spray timing on 2011-09-07
print(f'Mode: {pd.to_datetime(df_spray[df_spray["Date"]=="2011-09-07"]["Time"]).mode()}')
print(f'Median: {pd.to_datetime(df_spray[df_spray["Date"]=="2011-09-07"]["Time"]).median()}')
print(f'Min: {pd.to_datetime(df_spray[df_spray["Date"]=="2011-09-07"]["Time"]).min()}')
print(f'Max: {pd.to_datetime(df_spray[df_spray["Date"]=="2011-09-07"]["Time"]).max()}')
# Out:
# Mode: 0   2022-12-13 19:44:32
# Name: Time, dtype: datetime64[ns]
# Median: 2022-12-13 20:11:06
# Min: 2022-12-13 19:42:12
# Max: 2022-12-13 21:41:10

# %%
# Plotting histogram of spray timing
df_spray_0907 = df_spray[df_spray["Date"]=='2011-09-07']
plt.figure(figsize =(15,8))
plt.xticks(rotation=90)
df_spray_1 = df_spray_0907[df_spray_0907["Time"].notnull()]
plt.hist(pd.to_datetime(df_spray_1['Time']),bins = 20)
plt.title("Histogram for Spray Timing on 2011-09-07")
plt.ylabel("Count")
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
# replacing null values in df_spray "Time" column with mode timing
df_spray["Time"].fillna("7:44:32 PM", inplace = True)
df_spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14835 non-null  object
#  1   Time       14835 non-null  object
#  2   Latitude   14835 non-null  float64
#  3   Longitude  14835 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 463.7+ KB

# %%
#create datetime column:
df_spray["datetime"] = df_spray["Date"] + " " + df_spray["Time"]
df_spray.head()
# Out:
#          Date        Time   Latitude  Longitude               datetime
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163  2011-08-29 6:56:58 PM
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163  2011-08-29 6:57:08 PM
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157  2011-08-29 6:57:18 PM
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158  2011-08-29 6:57:28 PM
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858  2011-08-29 6:57:38 PM

# %%
# converting to python readable date-time format
df_spray['datetime'] = pd.to_datetime(df_spray['datetime'])

# %%
# extract date components before setting it to index
df_spray['Year'] = df_spray['datetime'].apply(lambda x: x.year)
df_spray['Month'] = df_spray['datetime'].apply(lambda x: x.month)
df_spray['Week'] = df_spray['datetime'].apply(lambda x: x.week)
df_spray['DayOfWeek'] = df_spray['datetime'].apply(lambda x: x.dayofweek)

# %%
# set datetime column to be the index
df_spray.set_index('datetime', inplace=True)

# %%
df_spray.head()
# Out:
#                            Date        Time   Latitude  Longitude  Year  \
# datetime
# 2011-08-29 18:56:58  2011-08-29  6:56:58 PM  42.391623 -88.089163  2011
# 2011-08-29 18:57:08  2011-08-29  6:57:08 PM  42.391348 -88.089163  2011
# 2011-08-29 18:57:18  2011-08-29  6:57:18 PM  42.391022 -88.089157  2011
# 2011-08-29 18:57:28  2011-08-29  6:57:28 PM  42.390637 -88.089158  2011
# 2011-08-29 18:57:38  2011-08-29  6:57:38 PM  42.390410 -88.088858  2011
#
#                      Month  Week  DayOfWeek
# datetime
# 2011-08-29 18:56:58      8    35          0
# 2011-08-29 18:57:08      8    35          0
# 2011-08-29 18:57:18      8    35          0
# 2011-08-29 18:57:28      8    35          0
# 2011-08-29 18:57:38      8    35          0

# %%
# Date range:
print(f'From:{df_spray["Date"].min()}')
print(f"To:{df_spray['Date'].max()}")
# Out:
# From:2011-08-29
# To:2013-09-05

# %% [markdown]
# ### Dataset: `weather.csv`

# %% [markdown]
# It is believed that hot and dry conditions are more favorable for West Nile virus than cold and wet. We provide you with the dataset from NOAA of the weather conditions of 2007 to 2014, during the months of the tests.
#
# Station 1: CHICAGO O'HARE INTERNATIONAL AIRPORT Lat: 41.995 Lon: -87.933 Elev: 662 ft. above sea level
# Station 2: CHICAGO MIDWAY INTL ARPT Lat: 41.786 Lon: -87.752 Elev: 612 ft. above sea level

# %%
df_weather.head(50)
# Out:
#     Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0         1  2007-05-01    83    50   67     14        51      56    0    2
# 1         2  2007-05-01    84    52   68      M        51      57    0    3
# 2         1  2007-05-02    59    42   51     -3        42      47   14    0
# 3         2  2007-05-02    60    43   52      M        42      47   13    0
# 4         1  2007-05-03    66    46   56      2        40      48    9    0
# 5         2  2007-05-03    67    48   58      M        40      50    7    0
# 6         1  2007-05-04    66    49   58      4        41      50    7    0
# 7         2  2007-05-04    78    51    M      M        42      50    M    M
# 8         1  2007-05-05    66    53   60      5        38      49    5    0
# 9         2  2007-05-05    66    54   60      M        39      50    5    0
# 10        1  2007-05-06    68    49   59      4        30      46    6    0
# 11        2  2007-05-06    68    52   60      M        30      46    5    0
# 12        1  2007-05-07    83    47   65     10        41      54    0    0
# 13        2  2007-05-07    84    50   67      M        39      53    0    2
# 14        1  2007-05-08    82    54   68     12        58      62    0    3
# 15        2  2007-05-08    80    60   70      M        57      63    0    5
# 16        1  2007-05-09    77    61   69     13        59      63    0    4
# 17        2  2007-05-09    76    63   70      M        60      63    0    5
# 18        1  2007-05-10    84    56   70     14        52      60    0    5
# 19        2  2007-05-10    83    59   71      M        52      61    0    6
# 20        1  2007-05-11    70    51   61      4        42      51    4    0
# 21        2  2007-05-11    73    49   61      M        44      51    4    0
# 22        1  2007-05-12    64    46   55     -2        36      46   10    0
# 23        2  2007-05-12    65    47   56      M        37      46    9    0
# 24        1  2007-05-13    69    43   56     -2        33      46    9    0
# 25        2  2007-05-13    69    44   57      M        32      46    8    0
# 26        1  2007-05-14    90    56   73     15        47      59    0    8
# 27        2  2007-05-14    90    54   72      M        45      58    0    7
# 28        1  2007-05-15    80    57   69     11        56      61    0    4
# 29        2  2007-05-15    82    56   69      M        56      61    0    4
# 30        1  2007-05-16    66    44   55     -4        43      48   10    0
# 31        2  2007-05-16    64    45   55      M        42      47   10    0
# 32        1  2007-05-17    62    43   53     -6        32      43   12    0
# 33        2  2007-05-17    61    44   53      M        32      43   12    0
# 34        1  2007-05-18    71    42   57     -3        30      46    8    0
# 35        2  2007-05-18    70    43   57      M        31      47    8    0
# 36        1  2007-05-19    80    56   68      8        39      53    0    3
# 37        2  2007-05-19    80    56   68      M        37      53    0    3
# 38        1  2007-05-20    69    43   56     -5        40      44    9    0
# 39        2  2007-05-20    69    44   57      M        41      45    8    0
# 40        1  2007-05-21    80    44   62      1        50      56    3    0
# 41        2  2007-05-21    79    46   63      M        50      57    2    0
# 42        1  2007-05-22    87    55   71     10        46      58    0    6
# 43        2  2007-05-22    87    60   74      M        44      58    0    9
# 44        1  2007-05-23    89    60   75     14        49      61    0   10
# 45        2  2007-05-23    89    66   78      M        48      61    0   13
# 46        1  2007-05-24    88    63   76     14        54      63    0   11
# 47        2  2007-05-24    88    66   77      M        53      63    0   12
# 48        1  2007-05-25    70    56   63      1        44      53    2    0
# 49        2  2007-05-25    66    57   62      M        46      53    3    0
#
#    Sunrise Sunset     CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0     0448   1849                 0      M      0.0        0.00       29.10
# 1        -      -                 M      M        M        0.00       29.18
# 2     0447   1850          BR     0      M      0.0        0.00       29.38
# 3        -      -       BR HZ     M      M        M        0.00       29.44
# 4     0446   1851                 0      M      0.0        0.00       29.39
# 5        -      -          HZ     M      M        M        0.00       29.46
# 6     0444   1852          RA     0      M      0.0           T       29.31
# 7        -      -                 M      M        M        0.00       29.36
# 8     0443   1853                 0      M      0.0           T       29.40
# 9        -      -                 M      M        M           T       29.46
# 10    0442   1855                 0      M      0.0        0.00       29.57
# 11       -      -                 M      M        M        0.00       29.62
# 12    0441   1856          RA     0      M      0.0           T       29.38
# 13       -      -                 M      M        M        0.00       29.44
# 14    0439   1857          BR     0      M      0.0        0.00       29.29
# 15       -      -          HZ     M      M        M           T       29.36
# 16    0438   1858       BR HZ     0      M      0.0        0.13       29.21
# 17       -      -       BR HZ     M      M        M        0.02       29.28
# 18    0437   1859          BR     0      M      0.0        0.00       29.20
# 19       -      -       BR HZ     M      M        M        0.00       29.26
# 20    0436   1860                 0      M      0.0        0.00       29.33
# 21       -      -                 M      M        M        0.00       29.39
# 22    0435   1901                 0      M      0.0        0.00       29.49
# 23       -      -                 M      M        M        0.00       29.54
# 24    0434   1902                 0      M      0.0        0.00       29.49
# 25       -      -                 M      M        M        0.00       29.55
# 26    0433   1903                 0      M      0.0        0.00       29.23
# 27       -      -                 M      M        M        0.00       29.31
# 28    0432   1904       RA BR     0      M      0.0        0.38       29.13
# 29       -      -  TSRA RA BR     M      M        M        0.60       29.19
# 30    0431   1905       RA BR     0      M      0.0        0.14       29.33
# 31       -      -       RA BR     M      M        M        0.07       29.39
# 32    0430   1906                 0      M      0.0        0.00       29.55
# 33       -      -                 M      M        M        0.00       29.62
# 34    0429   1907                 0      M      0.0        0.00       29.53
# 35       -      -                 M      M        M        0.00       29.60
# 36    0428   1908                 0      M      0.0        0.00       29.34
# 37       -      -                 M      M        M        0.00       29.41
# 38    0427   1909     RA VCTS     0      M      0.0        0.07       29.38
# 39       -      -     TSRA RA     M      M        M        0.11       29.44
# 40    0426   1910                 0      M      0.0        0.00       29.33
# 41       -      -                 M      M        M        0.00       29.39
# 42    0425   1911                 0      M      0.0        0.00       29.34
# 43       -      -                 M      M        M        0.00       29.41
# 44    0425   1912                 0      M      0.0        0.00       29.39
# 45       -      -                 M      M        M        0.00       29.47
# 46    0424   1913       RA HZ     0      M      0.0        0.02       29.41
# 47       -      -       RA HZ     M      M        M           T       29.47
# 48    0423   1914                 0      M      0.0           T       29.51
# 49       -      -       RA BR     M      M        M        0.09       29.57
#
#    SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0     29.82          1.7         27      9.2
# 1     29.82          2.7         25      9.6
# 2     30.09         13.0          4     13.4
# 3     30.08         13.3          2     13.4
# 4     30.12         11.7          7     11.9
# 5     30.12         12.9          6     13.2
# 6     30.05         10.4          8     10.8
# 7     30.04         10.1          7     10.4
# 8     30.10         11.7          7     12.0
# 9     30.09         11.2          7     11.5
# 10    30.29         14.4         11     15.0
# 11    30.28         13.8         10     14.5
# 12    30.12          8.6         18     10.5
# 13    30.12          8.5         17      9.9
# 14    30.03          2.7         11      5.8
# 15    30.02          2.5          8      5.4
# 16    29.94          3.9          9      6.2
# 17    29.93          3.9          7      5.9
# 18    29.92          0.7         17      4.1
# 19    29.91          2.0          9      3.9
# 20    30.04         11.3          3     12.9
# 21    30.03         11.7         36     12.8
# 22    30.20         12.4          3     12.9
# 23    30.19         12.7          1     13.0
# 24    30.24          6.6         14      8.1
# 25    30.24          6.4         11      7.6
# 26    29.97         16.9         21     17.3
# 27    29.98         14.1         21     14.6
# 28    29.84          8.1         27     12.3
# 29    29.83          8.1         25     10.8
# 30    30.03          7.8         36     12.2
# 31    30.03          8.0         36     11.8
# 32    30.27         10.5          3     11.3
# 33    30.27         11.7          1     12.2
# 34    30.25          5.4         25      7.5
# 35    30.26          3.4         22      5.5
# 36    30.08         11.1         24     11.4
# 37    30.08         11.1         23     11.4
# 38    30.11         10.4          4     10.7
# 39    30.11          8.6          3      9.7
# 40    30.06          6.3         11      8.2
# 41    30.05          6.3         10      7.8
# 42    30.06         10.0         18     10.2
# 43    30.05         10.1         16     10.6
# 44    30.10         11.4         19     11.8
# 45    30.10         10.9         18     11.2
# 46    30.11         14.9         21     17.3
# 47    30.10         13.8         20     15.2
# 48    30.24          4.9          5      8.8
# 49    30.23          4.5          5      8.2

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   object
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   object
#  5   Depart       2944 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2944 non-null   object
#  8   Heat         2944 non-null   object
#  9   Cool         2944 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   object
#  14  Water1       2944 non-null   object
#  15  SnowFall     2944 non-null   object
#  16  PrecipTotal  2944 non-null   object
#  17  StnPressure  2944 non-null   object
#  18  SeaLevel     2944 non-null   object
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2944 non-null   object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 506.1+ KB

# %%
# converting Date in train dataset to python readable date-time format
df_weather['Date'] = pd.to_datetime(df_weather['Date'])

# %%
df_weather.head()
# Out:
#    Station       Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1 2007-05-01    83    50   67     14        51      56    0    2
# 1        2 2007-05-01    84    52   68      M        51      57    0    3
# 2        1 2007-05-02    59    42   51     -3        42      47   14    0
# 3        2 2007-05-02    60    43   52      M        42      47   13    0
# 4        1 2007-05-03    66    46   56      2        40      48    9    0
#
#   Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0    0448   1849             0      M      0.0        0.00       29.10
# 1       -      -             M      M        M        0.00       29.18
# 2    0447   1850      BR     0      M      0.0        0.00       29.38
# 3       -      -   BR HZ     M      M        M        0.00       29.44
# 4    0446   1851             0      M      0.0        0.00       29.39
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    29.82          1.7         27      9.2
# 1    29.82          2.7         25      9.6
# 2    30.09         13.0          4     13.4
# 3    30.08         13.3          2     13.4
# 4    30.12         11.7          7     11.9

# %%
# replace M with NaN
df_weather.replace(to_replace= "M", value=np.NaN, inplace = True)
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   datetime64[ns]
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2933 non-null   object
#  5   Depart       1472 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2940 non-null   object
#  8   Heat         2933 non-null   object
#  9   Cool         2933 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        1472 non-null   object
#  14  Water1       0 non-null      float64
#  15  SnowFall     1472 non-null   object
#  16  PrecipTotal  2942 non-null   object
#  17  StnPressure  2940 non-null   object
#  18  SeaLevel     2935 non-null   object
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2941 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(14)
# memory usage: 506.1+ KB

# %% [markdown]
# ##### Tavg

# %%
# replacing missing values in Tavg with cal avg of Tmax and Tmin 
df_weather["Tavg"] = df_weather.loc[:,["Tmax","Tmin"]].mean(axis = 1).apply(np.ceil)
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   datetime64[ns]
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   float64
#  5   Depart       1472 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2940 non-null   object
#  8   Heat         2933 non-null   object
#  9   Cool         2933 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        1472 non-null   object
#  14  Water1       0 non-null      float64
#  15  SnowFall     1472 non-null   object
#  16  PrecipTotal  2942 non-null   object
#  17  StnPressure  2940 non-null   object
#  18  SeaLevel     2935 non-null   object
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2941 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(13)
# memory usage: 506.1+ KB

# %% [markdown]
# ##### Depart

# %%
# breaking down dataset into respective stations
df_weather_1 = df_weather[df_weather["Station"]==1]
df_weather_2 = df_weather[df_weather["Station"]==2]
df_weather_1 = df_weather_1.reset_index()
df_weather_2 = df_weather_2.reset_index()

# %%
# checking missing values in Depart column
display(df_weather_1.head())
display(df_weather_2.head())
# Out:
#    index  Station       Date  Tmax  Tmin  Tavg Depart  DewPoint WetBulb Heat  \
# 0      0        1 2007-05-01    83    50  67.0     14        51      56    0
# 1      2        1 2007-05-02    59    42  51.0     -3        42      47   14
# 2      4        1 2007-05-03    66    46  56.0      2        40      48    9
# 3      6        1 2007-05-04    66    49  58.0      4        41      50    7
# 4      8        1 2007-05-05    66    53  60.0      5        38      49    5
#
#   Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal StnPressure  \
# 0    2    0448   1849             0     NaN      0.0        0.00       29.10
# 1    0    0447   1850      BR     0     NaN      0.0        0.00       29.38
# 2    0    0446   1851             0     NaN      0.0        0.00       29.39
# 3    0    0444   1852      RA     0     NaN      0.0           T       29.31
# 4    0    0443   1853             0     NaN      0.0           T       29.40
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    29.82          1.7         27      9.2
# 1    30.09         13.0          4     13.4
# 2    30.12         11.7          7     11.9
# 3    30.05         10.4          8     10.8
# 4    30.10         11.7          7     12.0
#    index  Station       Date  Tmax  Tmin  Tavg Depart  DewPoint WetBulb Heat  \
# 0      1        2 2007-05-01    84    52  68.0    NaN        51      57    0
# 1      3        2 2007-05-02    60    43  52.0    NaN        42      47   13
# 2      5        2 2007-05-03    67    48  58.0    NaN        40      50    7
# 3      7        2 2007-05-04    78    51  65.0    NaN        42      50  NaN
# 4      9        2 2007-05-05    66    54  60.0    NaN        39      50    5
#
#   Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal StnPressure  \
# 0    3       -      -           NaN     NaN      NaN        0.00       29.18
# 1    0       -      -   BR HZ   NaN     NaN      NaN        0.00       29.44
# 2    0       -      -      HZ   NaN     NaN      NaN        0.00       29.46
# 3  NaN       -      -           NaN     NaN      NaN        0.00       29.36
# 4    0       -      -           NaN     NaN      NaN           T       29.46
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    29.82          2.7         25      9.6
# 1    30.08         13.3          2     13.4
# 2    30.12         12.9          6     13.2
# 3    30.04         10.1          7     10.4
# 4    30.09         11.2          7     11.5

# %%
# calculate 30 year normal temperature from station 1 and merge to station 2 dataset
df_weather_1["Depart"] = df_weather_1["Depart"].astype(float)
df_weather_2["30_yr_temp"]= df_weather_1["Tavg"] - df_weather_1["Depart"].astype(float)

# %%
# plotting trend for 30 year normal temperature
plt.figure(figsize=(12,8))
plt.plot(df_weather_2["30_yr_temp"])
plt.title("30 Year Normal Temperature")
plt.ylabel("Temperature")
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
# Calculate Depart value for station 2
df_weather_2["Depart"] = df_weather_2["Tavg"] - df_weather_2["30_yr_temp"]
df_weather_2.head()
# Out:
#    index  Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint WetBulb Heat  \
# 0      1        2 2007-05-01    84    52  68.0    15.0        51      57    0
# 1      3        2 2007-05-02    60    43  52.0    -2.0        42      47   13
# 2      5        2 2007-05-03    67    48  58.0     4.0        40      50    7
# 3      7        2 2007-05-04    78    51  65.0    11.0        42      50  NaN
# 4      9        2 2007-05-05    66    54  60.0     5.0        39      50    5
#
#   Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal StnPressure  \
# 0    3       -      -           NaN     NaN      NaN        0.00       29.18
# 1    0       -      -   BR HZ   NaN     NaN      NaN        0.00       29.44
# 2    0       -      -      HZ   NaN     NaN      NaN        0.00       29.46
# 3  NaN       -      -           NaN     NaN      NaN        0.00       29.36
# 4    0       -      -           NaN     NaN      NaN           T       29.46
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed  30_yr_temp
# 0    29.82          2.7         25      9.6        53.0
# 1    30.08         13.3          2     13.4        54.0
# 2    30.12         12.9          6     13.2        54.0
# 3    30.04         10.1          7     10.4        54.0
# 4    30.09         11.2          7     11.5        55.0

# %%
plt.figure(figsize=(12,8))
plt.plot(df_weather_2["Depart"])
plt.plot(df_weather_1["Depart"])

# %% [markdown]
# ##### Wet Bulb

# %%
# checking for null values
display(df_weather_1[df_weather_1["WetBulb"].isnull()])
display(df_weather_2[df_weather_2["WetBulb"].isnull()])
# Out:
#       index  Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint WetBulb  \
# 424     848        1 2009-06-26    86    69  78.0     7.0        60     NaN
# 1205   2410        1 2013-08-10    81    64  73.0     0.0        57     NaN
# 1206   2412        1 2013-08-11    81    60  71.0    -2.0        61     NaN
#
#      Heat Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal  \
# 424     0   13    0418   1931             0     NaN      0.0        0.00
# 1205    0    8    0454   1900             0     NaN      0.0        0.00
# 1206    0    6    0455   1859      RA     0     NaN      0.0        0.01
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 424          NaN    29.85          6.4          4      8.2
# 1205         NaN    30.08          5.3          5      6.5
# 1206       29.35    30.07          2.0         27      3.0
#       index  Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint WetBulb  \
# 1207   2415        2 2013-08-12    85    69  77.0     4.0        63     NaN
#
#      Heat Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal  \
# 1207    0   12       -      -      RA   NaN     NaN      NaN        0.66
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed  30_yr_temp
# 1207       29.27    29.92          4.5         26      7.7        73.0

# %%
# replace null values
df_weather_1["WetBulb"]=df_weather_1["WetBulb"].fillna(method="ffill").astype(float)
df_weather_2["WetBulb"]=df_weather_2["WetBulb"].fillna(method="ffill").astype(float)

# %% [markdown]
# ##### Heat/Cool

# %%
# Port over Heat values from station 1 to replace null values
for i in df_weather_2.index:
    if df_weather_2.loc[i,"Heat"] is np.NaN:
        df_weather_2.loc[i,"Heat"] = df_weather_1.loc[i,"Heat"]
        
# Port over Cool values from station 1 to replace null values
for i in df_weather_2.index:
    if df_weather_2.loc[i,"Cool"] is np.NaN:
        df_weather_2.loc[i,"Cool"] = df_weather_1.loc[i,"Cool"]

# %%
# change to float
df_weather_1["Heat"] = df_weather_1["Heat"].astype(float) 
df_weather_2["Heat"] = df_weather_2["Heat"].astype(float)

# %%
# change to float
df_weather_1["Cool"] = df_weather_1["Cool"].astype(float) 
df_weather_2["Cool"] = df_weather_2["Cool"].astype(float)

# %% [markdown]
# ##### Sunrise/Sunset

# %%
# Check on unique values for sunrise in station 2
df_weather_2["Sunrise"].unique()
# Out:
# array(['-'], dtype=object)

# %%
# Check on unique values for sunset in station 2
df_weather_2["Sunset"].unique()
# Out:
# array(['-'], dtype=object)

# %%
# Port over Sunrise values from station 1 to replace "-" values
for i in df_weather_2.index:
    if df_weather_2.loc[i,"Sunrise"] is "-":
        df_weather_2.loc[i,"Sunrise"] = df_weather_1.loc[i,"Sunrise"]

# Port over Sunset values from station 1 to replace "-" values
for i in df_weather_2.index:
    if df_weather_2.loc[i,"Sunset"] is "-":
        df_weather_2.loc[i,"Sunset"] = df_weather_1.loc[i,"Sunset"]

# %%
df_weather_2.head()
# Out:
#    index  Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  \
# 0      1        2 2007-05-01    84    52  68.0    15.0        51     57.0
# 1      3        2 2007-05-02    60    43  52.0    -2.0        42     47.0
# 2      5        2 2007-05-03    67    48  58.0     4.0        40     50.0
# 3      7        2 2007-05-04    78    51  65.0    11.0        42     50.0
# 4      9        2 2007-05-05    66    54  60.0     5.0        39     50.0
#
#    Heat  Cool Sunrise Sunset CodeSum Depth  Water1 SnowFall PrecipTotal  \
# 0   0.0   3.0    0448   1849           NaN     NaN      NaN        0.00
# 1  13.0   0.0    0447   1850   BR HZ   NaN     NaN      NaN        0.00
# 2   7.0   0.0    0446   1851      HZ   NaN     NaN      NaN        0.00
# 3   7.0   0.0    0444   1852           NaN     NaN      NaN        0.00
# 4   5.0   0.0    0443   1853           NaN     NaN      NaN           T
#
#   StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed  30_yr_temp
# 0       29.18    29.82          2.7         25      9.6        53.0
# 1       29.44    30.08         13.3          2     13.4        54.0
# 2       29.46    30.12         12.9          6     13.2        54.0
# 3       29.36    30.04         10.1          7     10.4        54.0
# 4       29.46    30.09         11.2          7     11.5        55.0

# %%
# convert sunrise to python readable time format
df_weather_1["Sunrise_1"] = pd.to_datetime(df_weather_1['Sunrise'], format='%H%M')
df_weather_2["Sunrise_1"] = pd.to_datetime(df_weather_2['Sunrise'], format='%H%M')

# %%
# changing sunset values with e.g. 1860 to 1900, so that datatime method can convert values. 
# weather_1
for i in range(len(df_weather_1)):
    a = list((df_weather_1.loc[i,"Sunset"]))
    if a[2] == '6':
        a[2] = '0'
        a[1] = str(int(a[1]) + 1)
        df_weather_1.loc[i,"Sunset"] = ''.join(a)

#weather_2
for i in range(len(df_weather_2)):
    a = list((df_weather_2.loc[i,"Sunset"]))
    if a[2] == '6':
        a[2] = '0'
        a[1] = str(int(a[1]) + 1)
        df_weather_2.loc[i,"Sunset"] = ''.join(a)

# %%
# convert sunrise to python readable time format
df_weather_1["Sunset_1"] = pd.to_datetime(df_weather_1['Sunset'], format='%H%M')
df_weather_2["Sunset_1"] = pd.to_datetime(df_weather_2['Sunset'], format='%H%M')

# %%
# find delta duration between sunrise and sunset
df_weather_1["daylight_duration"] = df_weather_1["Sunset_1"] - df_weather_1["Sunrise_1"]
df_weather_2["daylight_duration"] = df_weather_2["Sunset_1"] - df_weather_2["Sunrise_1"]

# %%
df_weather_2["daylight_duration"].unique()
# Out:
# array([50460000000000, 50580000000000, 50700000000000, 50880000000000,
#        51000000000000, 51180000000000, 51300000000000, 51480000000000,
#        51600000000000, 51720000000000, 51840000000000, 51960000000000,
#        52080000000000, 52200000000000, 52320000000000, 52440000000000,
#        52560000000000, 52680000000000, 52800000000000, 52920000000000,
#        53040000000000, 53160000000000, 53220000000000, 53340000000000,
#        53460000000000, 53580000000000, 53640000000000, 53700000000000,
#        53760000000000, 53880000000000, 53940000000000, 54060000000000,
#        54180000000000, 54240000000000, 54360000000000, 54420000000000,
#        54480000000000, 54540000000000, 54600000000000, 54660000000000,
#        54720000000000, 54780000000000, 54840000000000, 54300000000000,
#        54120000000000, 53820000000000, 53520000000000, 53400000000000,
#        53280000000000, 52740000000000, 52620000000000, 52500000000000,
#        52380000000000, 52260000000000, 52140000000000, 51360000000000,
#        51060000000000, 50940000000000, 50760000000000, 50640000000000,
#        50520000000000, 50340000000000, 50220000000000, 50100000000000,
#        49920000000000, 49800000000000, 49620000000000, 49500000000000,
#        49320000000000, 49200000000000, 49020000000000, 48840000000000,
#        48660000000000, 48540000000000, 48360000000000, 48180000000000,
#        48060000000000, 47880000000000, 47760000000000, 47580000000000,
#        47400000000000, 47280000000000, 47100000000000, 46920000000000,
#        46800000000000, 46620000000000, 46440000000000, 46260000000000,
#        46140000000000, 45960000000000, 45780000000000, 45660000000000,
#        45480000000000, 45300000000000, 45120000000000, 44880000000000,
#        44700000000000, 44460000000000, 44340000000000, 44160000000000,
#        43980000000000, 43800000000000, 43680000000000, 43500000000000,
#        43320000000000, 43140000000000, 43020000000000, 42840000000000,
#        42660000000000, 42480000000000, 42360000000000, 42180000000000,
#        42000000000000, 41820000000000, 41640000000000, 41460000000000,
#        41340000000000, 41160000000000, 40980000000000, 40860000000000,
#        40680000000000, 40500000000000, 40320000000000, 40140000000000,
#        40020000000000, 39840000000000, 39660000000000, 39540000000000,
#        39360000000000, 39180000000000, 39000000000000, 38880000000000,
#        38700000000000, 38580000000000, 38400000000000, 38220000000000,
#        38100000000000, 37920000000000, 37800000000000, 37620000000000,
#        37440000000000], dtype='timedelta64[ns]')

# %% [markdown]
# ##### Codesum

# %%
# replace blank values with Clear
df_weather_1["CodeSum"].replace(to_replace=' ',value="Clear", inplace = True)
df_weather_2["CodeSum"].replace(to_replace=' ',value="Clear", inplace = True)

# %%
display(df_weather_1["CodeSum"].unique())
display(df_weather_2["CodeSum"].unique())
# Out:
# array(['Clear', 'BR', 'RA', 'BR HZ', 'RA BR', 'RA VCTS', 'RA HZ',
#        'TSRA RA BR HZ', 'HZ', 'TSRA BR HZ', 'TSRA RA BR', 'TSRA RA HZ',
#        'TSRA BR HZ VCTS', 'TSRA', 'TSRA BR HZ FU', 'BR HZ FU',
#        'TSRA RA VCTS', 'HZ VCTS', 'RA BR VCTS', 'TSRA RA BR VCTS',
#        'DZ BR', 'TS TSRA RA BR HZ', 'RA BR HZ', 'TSRA RA',
#        'TS TSRA RA BR', 'TS RA BR', 'TS TSRA RA', 'TS TSRA RA BR VCTS',
#        'TS RA', 'TSRA BR', 'RA DZ FG+ BCFG BR', 'RA FG+ MIFG BR', 'RA DZ',
#        'RA DZ BR', 'TSRA RA FG+ FG BR', 'TSRA DZ FG+ FG BR HZ', 'TS TSRA',
#        'TSRA HZ', 'TS', 'FG+ BR HZ', 'TS TSRA BR HZ', 'DZ BR HZ',
#        'TS TSRA BR', 'RA BR FU', 'TS BR HZ', 'FG+ BR', 'FG+ MIFG BR',
#        'TSRA RA FG BR', 'DZ', 'RA DZ BR HZ', 'TS BR', 'TS RA FG+ FG BR',
#        'RA DZ FG+ FG BR', 'RA BR SQ', 'RA FG BR', 'RA BR HZ FU',
#        'MIFG BCFG BR', 'TSRA RA FG+ FG BR HZ', 'TSRA DZ BR HZ',
#        'TS TSRA RA FG BR HZ', 'RA DZ FG+ BR', 'TSRA FG+ BR HZ',
#        'FG+ FG BR HZ', 'FG BR HZ', 'TS RA BR HZ', 'BCFG BR', 'RA SN'],
#       dtype=object)
# array(['Clear', 'BR HZ', 'HZ', 'TSRA RA BR', 'RA BR', 'TSRA RA', 'RA HZ',
#        'TSRA BR HZ', 'RA BR HZ VCTS', 'RA', 'TSRA RA HZ', 'TSRA RA HZ FU',
#        'BR', 'TSRA HZ', 'VCTS', 'TS TSRA RA BR HZ VCTS', 'TS TSRA BR HZ',
#        'RA BR HZ', 'TSRA RA BR VCTS', 'TSRA RA DZ BR HZ', 'TSRA',
#        'TS TSRA RA BR', 'TS RA BR', 'TS TSRA RA BR HZ', 'TS TSRA BR',
#        'TSRA RA BR HZ', 'RA BCFG BR', 'TSRA BR', 'RA DZ', 'RA DZ BR',
#        'TS TSRA RA HZ', 'TS BR', 'RA BR SQ', 'TS TSRA RA', 'TS RA',
#        'TSRA RA VCTS', 'TSRA RA BR HZ VCTS', 'BR VCTS', 'RA SN',
#        'TSRA RA DZ BR', 'DZ BR', 'DZ BR HZ', 'DZ', 'FG+ FG BR', 'FG+ BR',
#        'TSRA FG+ BR', 'RA DZ BR HZ', 'RA DZ SN', 'FG+ FG BR HZ',
#        'TS TSRA RA FG BR', 'TS BR HZ', 'BR HZ VCFG', 'TSRA RA FG+ BR',
#        'TS TSRA RA VCTS', 'FU', 'TS', 'TS TSRA VCFG', 'TS TSRA HZ',
#        'TS TSRA GR RA BR', 'HZ FU', 'RA BR HZ FU', 'FG+ BCFG BR',
#        'TSRA RA FG+ FG BR', 'FG+', 'TSRA BR SQ', 'RA BR HZ VCFG',
#        'RA FG+ BR', 'FG BR HZ', 'TS HZ', 'RA DZ FG+ BR HZ', 'RA BR VCFG',
#        'TS TSRA', 'RA SN BR'], dtype=object)

# %% [markdown]
# ##### Depth

# %%
# check on Depth unique values
display(df_weather_1["Depth"].unique())
display(df_weather_2["Depth"].unique())
# Out:
# array(['0'], dtype=object)
# array([nan], dtype=object)

# %%
# drop Depth since all 0 values
df_weather_1.drop("Depth", axis = 1, inplace = True)

# drop Depth since all nan values
df_weather_2.drop("Depth", axis = 1, inplace = True)

# %% [markdown]
# ##### Water1

# %%
# drop Water1, since all null values
df_weather_1.drop("Water1", axis = 1, inplace = True)
df_weather_2.drop("Water1", axis = 1, inplace = True)

# %% [markdown]
# ##### SnowFall

# %%
# check on SnowFall unique values
display(df_weather_1["SnowFall"].unique())
display(df_weather_2["SnowFall"].unique())
# Out:
# array(['0.0', '  T', '0.1'], dtype=object)
# array([nan], dtype=object)

# %%
# replace Trace values with 0 - since a trace is anything less than can be measured
df_weather_1["SnowFall"].replace(to_replace= '  T', value="0.0", inplace = True)

# %%
# Port over SnowFall values from station 1 to replace "nan" values
for i in df_weather_2.index:
    if df_weather_2.loc[i,"SnowFall"] is np.NaN:
        df_weather_2.loc[i,"SnowFall"] = df_weather_1.loc[i,"SnowFall"]

# %%
# change to float datatype
df_weather_1["SnowFall"] = df_weather_1["SnowFall"].astype(float)
df_weather_2["SnowFall"] = df_weather_2["SnowFall"].astype(float)

# %% [markdown]
# ##### Precipitotal

# %%
display(df_weather_1["PrecipTotal"].unique())
display(df_weather_2["PrecipTotal"].unique())
# Out:
# array(['0.00', '  T', '0.13', '0.38', '0.14', '0.07', '0.02', '1.01',
#        '0.04', '0.01', '0.19', '0.39', '0.42', '0.28', '0.58', '0.05',
#        '0.16', '0.15', '0.40', '0.30', '0.43', '0.11', '1.55', '0.17',
#        '0.03', '1.43', '0.26', '1.31', '0.06', '0.29', '0.41', '0.23',
#        '0.09', '1.33', '0.91', '0.37', '2.35', '0.24', '0.34', '0.18',
#        '0.36', '0.27', '0.33', '1.28', '0.76', '0.95', '0.08', '0.12',
#        '0.48', '0.52', '0.64', '1.24', '0.20', '0.72', '0.73', '1.61',
#        '0.74', '1.05', '2.43', '2.90', '1.23', '6.64', '1.44', '0.82',
#        '0.80', '0.32', '0.67', '0.55', '1.73', '0.44', '0.45', '3.97',
#        '0.25', '0.68', '0.63', '0.35', '0.93', '0.22', '0.75', '0.89',
#        '0.21', '0.46', '1.03', '0.60', '0.81', '0.97', '1.49', '1.02',
#        '0.59', '0.87', '0.85', '0.54', '0.79', '2.79', '3.64', '0.10',
#        '0.31', '2.24', '1.06', '1.88', '6.86', '0.71', '0.70', '1.11',
#        '0.65', '1.21', '0.77', '1.34', '0.47', '1.12', '0.57', '0.51',
#        '1.09', '0.56', '1.35', '0.84', '1.48', '0.92', '0.50', '1.04',
#        '2.09', '1.26', '2.60', '2.76', '0.98', '1.58'], dtype=object)
# array(['0.00', '  T', '0.02', '0.60', '0.07', '0.11', '0.09', '0.28',
#        '0.08', '0.53', '0.21', '0.32', '0.31', '0.27', '0.16', '0.93',
#        '0.34', '0.35', nan, '0.66', '0.24', '0.92', '0.01', '0.89',
#        '0.04', '0.97', '0.05', '0.06', '0.46', '0.23', '0.45', '0.83',
#        '0.42', '1.33', '0.48', '0.88', '1.96', '0.20', '0.25', '0.67',
#        '0.14', '0.17', '0.19', '0.15', '0.03', '0.41', '0.74', '0.71',
#        '1.46', '0.26', '0.30', '0.22', '1.31', '0.29', '0.12', '0.43',
#        '0.65', '1.22', '0.13', '0.50', '0.59', '2.68', '1.01', '0.62',
#        '3.07', '1.75', '0.86', '0.63', '1.03', '0.70', '1.38', '1.14',
#        '1.07', '0.87', '0.78', '1.12', '0.10', '0.61', '0.54', '1.19',
#        '0.44', '0.33', '0.84', '1.29', '1.05', '1.15', '0.72', '0.40',
#        '1.57', '1.30', '0.51', '1.23', '0.77', '3.15', '4.73', '0.52',
#        '1.60', '0.57', '0.37', '1.90', '0.18', '0.69', '2.17', '0.36',
#        '0.49', '0.39', '0.90', '0.38', '0.56', '0.55', '1.02', '3.66',
#        '1.25', '2.20', '0.85', '0.47', '0.96', '0.80', '0.68', '1.16',
#        '2.03', '1.43', '0.64', '0.73', '2.06', '3.31', '1.82', '3.17',
#        '1.61', '1.18'], dtype=object)

# %%
# replace Trace values with 0 - since a trace is anything less than can be measured
df_weather_1["PrecipTotal"].replace(to_replace= '  T', value="0.00", inplace = True)
df_weather_2["PrecipTotal"].replace(to_replace= '  T', value="0.00", inplace = True)

# %%
# replace null values for PrecipTotal for station 2 with rain fall from the previous day.
df_weather_2["PrecipTotal"]=df_weather_2["PrecipTotal"].fillna(method="ffill").astype(float)

# %%
# change to float datatype
df_weather_1["PrecipTotal"] = df_weather_1["PrecipTotal"].astype(float)

# %% [markdown]
# ##### StnPressure

# %%
# fill null values for StnPressure with previous day values
df_weather_1["StnPressure"] = df_weather_1["StnPressure"].fillna(method="ffill").astype(float)
df_weather_2["StnPressure"] = df_weather_2["StnPressure"].fillna(method="ffill").astype(float)

# %% [markdown]
# ##### SeaLevel

# %%
# fill null values for SeaLevel with previous day values
df_weather_1["SeaLevel"] = df_weather_1["SeaLevel"].fillna(method="ffill").astype(float)
df_weather_2["SeaLevel"] = df_weather_2["SeaLevel"].fillna(method="ffill").astype(float)

# %% [markdown]
# ##### AvgSpeed

# %%
# fill null values for AvgSpeed with previous day values
df_weather_2["AvgSpeed"] = df_weather_2["AvgSpeed"].fillna(method="ffill")

# %%
df_weather_1["AvgSpeed"] = df_weather_1["AvgSpeed"].astype(float)
df_weather_2["AvgSpeed"] = df_weather_2["AvgSpeed"].astype(float)

# %%
display(df_weather_1.info())
display(df_weather_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1472 non-null   int64
#  1   Station            1472 non-null   int64
#  2   Date               1472 non-null   datetime64[ns]
#  3   Tmax               1472 non-null   int64
#  4   Tmin               1472 non-null   int64
#  5   Tavg               1472 non-null   float64
#  6   Depart             1472 non-null   float64
#  7   DewPoint           1472 non-null   int64
#  8   WetBulb            1472 non-null   float64
#  9   Heat               1472 non-null   float64
#  10  Cool               1472 non-null   float64
#  11  Sunrise            1472 non-null   object
#  12  Sunset             1472 non-null   object
#  13  CodeSum            1472 non-null   object
#  14  SnowFall           1472 non-null   float64
#  15  PrecipTotal        1472 non-null   float64
#  16  StnPressure        1472 non-null   float64
#  17  SeaLevel           1472 non-null   float64
#  18  ResultSpeed        1472 non-null   float64
#  19  ResultDir          1472 non-null   int64
#  20  AvgSpeed           1472 non-null   float64
#  21  Sunrise_1          1472 non-null   datetime64[ns]
#  22  Sunset_1           1472 non-null   datetime64[ns]
#  23  daylight_duration  1472 non-null   timedelta64[ns]
# dtypes: datetime64[ns](3), float64(11), int64(6), object(3), timedelta64[ns](1)
# memory usage: 276.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1472 non-null   int64
#  1   Station            1472 non-null   int64
#  2   Date               1472 non-null   datetime64[ns]
#  3   Tmax               1472 non-null   int64
#  4   Tmin               1472 non-null   int64
#  5   Tavg               1472 non-null   float64
#  6   Depart             1472 non-null   float64
#  7   DewPoint           1472 non-null   int64
#  8   WetBulb            1472 non-null   float64
#  9   Heat               1472 non-null   float64
#  10  Cool               1472 non-null   float64
#  11  Sunrise            1472 non-null   object
#  12  Sunset             1472 non-null   object
#  13  CodeSum            1472 non-null   object
#  14  SnowFall           1472 non-null   float64
#  15  PrecipTotal        1472 non-null   float64
#  16  StnPressure        1472 non-null   float64
#  17  SeaLevel           1472 non-null   float64
#  18  ResultSpeed        1472 non-null   float64
#  19  ResultDir          1472 non-null   int64
#  20  AvgSpeed           1472 non-null   float64
#  21  30_yr_temp         1472 non-null   float64
#  22  Sunrise_1          1472 non-null   datetime64[ns]
#  23  Sunset_1           1472 non-null   datetime64[ns]
#  24  daylight_duration  1472 non-null   timedelta64[ns]
# dtypes: datetime64[ns](3), float64(12), int64(6), object(3), timedelta64[ns](1)
# memory usage: 287.6+ KB
# None

# %% [markdown]
# ##### Humidity

# %%
df_weather_1.head()
# Out:
#    index  Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  \
# 0      0        1 2007-05-01    83    50  67.0    14.0        51     56.0
# 1      2        1 2007-05-02    59    42  51.0    -3.0        42     47.0
# 2      4        1 2007-05-03    66    46  56.0     2.0        40     48.0
# 3      6        1 2007-05-04    66    49  58.0     4.0        41     50.0
# 4      8        1 2007-05-05    66    53  60.0     5.0        38     49.0
#
#    Heat  Cool Sunrise Sunset CodeSum  SnowFall  PrecipTotal  StnPressure  \
# 0   0.0   2.0    0448   1849   Clear       0.0          0.0        29.10
# 1  14.0   0.0    0447   1850      BR       0.0          0.0        29.38
# 2   9.0   0.0    0446   1851   Clear       0.0          0.0        29.39
# 3   7.0   0.0    0444   1852      RA       0.0          0.0        29.31
# 4   5.0   0.0    0443   1853   Clear       0.0          0.0        29.40
#
#    SeaLevel  ResultSpeed  ResultDir  AvgSpeed           Sunrise_1  \
# 0     29.82          1.7         27       9.2 1900-01-01 04:48:00
# 1     30.09         13.0          4      13.4 1900-01-01 04:47:00
# 2     30.12         11.7          7      11.9 1900-01-01 04:46:00
# 3     30.05         10.4          8      10.8 1900-01-01 04:44:00
# 4     30.10         11.7          7      12.0 1900-01-01 04:43:00
#
#              Sunset_1 daylight_duration
# 0 1900-01-01 18:49:00   0 days 14:01:00
# 1 1900-01-01 18:50:00   0 days 14:03:00
# 2 1900-01-01 18:51:00   0 days 14:05:00
# 3 1900-01-01 18:52:00   0 days 14:08:00
# 4 1900-01-01 18:53:00   0 days 14:10:00

# %%
# Relative humidity calculator
def RH_cal(Dp_f,T_f):
    Dp_c = (Dp_f-32)/1.8
    T_c = (T_f-32)/1.8
    RH = 100*((math.exp((17.625*Dp_c)/(243.04+Dp_c)))/(math.exp((17.625*T_c)/(243.04+T_c))))
    return RH

# %%
# calculate humidity values 
df_weather_1["Humidity"] = 0
for i in range(len(df_weather_1)):
    df_weather_1.loc[i,"Humidity"] = round(RH_cal(df_weather_1.loc[i,"DewPoint"],df_weather_1.loc[i,"Tavg"]),2)
    
df_weather_2["Humidity"] = 0
for i in range(len(df_weather_2)):
    df_weather_2.loc[i,"Humidity"] = round(RH_cal(df_weather_2.loc[i,"DewPoint"],df_weather_2.loc[i,"Tavg"]),2)

# %%
# display humidity values
display(df_weather_1.loc[:,["Humidity","Tavg","DewPoint"]].head())
display(df_weather_2.loc[:,["Humidity","Tavg","DewPoint"]].head())
# Out:
#    Humidity  Tavg  DewPoint
# 0     56.44  67.0        51
# 1     71.20  51.0        42
# 2     54.87  56.0        40
# 3     53.08  58.0        41
# 4     43.97  60.0        38
#    Humidity  Tavg  DewPoint
# 0     54.53  68.0        51
# 1     68.61  52.0        42
# 2     51.06  58.0        40
# 3     43.07  65.0        42
# 4     45.72  60.0        39

# %% [markdown]
# #### Add in time lag for features

# %%
# extract the date features before setting as index
df_weather_1['Year'] = df_weather_1['Date'].apply(lambda x: x.year)
df_weather_1['Month'] = df_weather_1['Date'].apply(lambda x: x.month)
df_weather_1['Week'] = df_weather_1['Date'].apply(lambda x: x.week)
df_weather_1['DayOfWeek'] = df_weather_1['Date'].apply(lambda x: x.dayofweek)

# %%
# changing index to date time
df_weather_1.set_index("Date", inplace = True)
df_weather_2.set_index("Date", inplace = True)

# %%
# sorting index
df_weather_1.sort_index(inplace = True)
df_weather_2.sort_index(inplace = True)

# %%
# shifting by 14 days, as 
df_weather_shifted_1 = df_weather_1.shift(14)
df_weather_shifted_2 = df_weather_2.shift(14)

# %%
# check on whether the dates are shifted by 14 days
display(df_weather_1.head())
display(df_weather_shifted_1.head(20))
df_weather_shifted_2.head(20)
# Out:
#             index  Station  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# Date
# 2007-05-01      0        1    83    50  67.0    14.0        51     56.0   0.0
# 2007-05-02      2        1    59    42  51.0    -3.0        42     47.0  14.0
# 2007-05-03      4        1    66    46  56.0     2.0        40     48.0   9.0
# 2007-05-04      6        1    66    49  58.0     4.0        41     50.0   7.0
# 2007-05-05      8        1    66    53  60.0     5.0        38     49.0   5.0
#
#             Cool Sunrise Sunset CodeSum  SnowFall  PrecipTotal  StnPressure  \
# Date
# 2007-05-01   2.0    0448   1849   Clear       0.0          0.0        29.10
# 2007-05-02   0.0    0447   1850      BR       0.0          0.0        29.38
# 2007-05-03   0.0    0446   1851   Clear       0.0          0.0        29.39
# 2007-05-04   0.0    0444   1852      RA       0.0          0.0        29.31
# 2007-05-05   0.0    0443   1853   Clear       0.0          0.0        29.40
#
#             SeaLevel  ResultSpeed  ResultDir  AvgSpeed           Sunrise_1  \
# Date
# 2007-05-01     29.82          1.7         27       9.2 1900-01-01 04:48:00
# 2007-05-02     30.09         13.0          4      13.4 1900-01-01 04:47:00
# 2007-05-03     30.12         11.7          7      11.9 1900-01-01 04:46:00
# 2007-05-04     30.05         10.4          8      10.8 1900-01-01 04:44:00
# 2007-05-05     30.10         11.7          7      12.0 1900-01-01 04:43:00
#
#                       Sunset_1 daylight_duration  Humidity  Year  Month  Week  \
# Date
# 2007-05-01 1900-01-01 18:49:00   0 days 14:01:00     56.44  2007      5    18
# 2007-05-02 1900-01-01 18:50:00   0 days 14:03:00     71.20  2007      5    18
# 2007-05-03 1900-01-01 18:51:00   0 days 14:05:00     54.87  2007      5    18
# 2007-05-04 1900-01-01 18:52:00   0 days 14:08:00     53.08  2007      5    18
# 2007-05-05 1900-01-01 18:53:00   0 days 14:10:00     43.97  2007      5    18
#
#             DayOfWeek
# Date
# 2007-05-01          1
# 2007-05-02          2
# 2007-05-03          3
# 2007-05-04          4
# 2007-05-05          5
#             index  Station  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# Date
# 2007-05-01    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-02    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-03    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-04    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-05    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-06    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-07    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-08    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-09    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-10    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-11    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-12    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-13    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-14    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-15    0.0      1.0  83.0  50.0  67.0    14.0      51.0     56.0   0.0
# 2007-05-16    2.0      1.0  59.0  42.0  51.0    -3.0      42.0     47.0  14.0
# 2007-05-17    4.0      1.0  66.0  46.0  56.0     2.0      40.0     48.0   9.0
# 2007-05-18    6.0      1.0  66.0  49.0  58.0     4.0      41.0     50.0   7.0
# 2007-05-19    8.0      1.0  66.0  53.0  60.0     5.0      38.0     49.0   5.0
# 2007-05-20   10.0      1.0  68.0  49.0  59.0     4.0      30.0     46.0   6.0
#
#             Cool Sunrise Sunset CodeSum  SnowFall  PrecipTotal  StnPressure  \
# Date
# 2007-05-01   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-02   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-03   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-04   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-05   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-06   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-07   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-08   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-09   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-10   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-11   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-12   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-13   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-14   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-15   2.0    0448   1849   Clear       0.0          0.0        29.10
# 2007-05-16   0.0    0447   1850      BR       0.0          0.0        29.38
# 2007-05-17   0.0    0446   1851   Clear       0.0          0.0        29.39
# 2007-05-18   0.0    0444   1852      RA       0.0          0.0        29.31
# 2007-05-19   0.0    0443   1853   Clear       0.0          0.0        29.40
# 2007-05-20   0.0    0442   1855   Clear       0.0          0.0        29.57
#
#             SeaLevel  ResultSpeed  ResultDir  AvgSpeed           Sunrise_1  \
# Date
# 2007-05-01       NaN          NaN        NaN       NaN                 NaT
# 2007-05-02       NaN          NaN        NaN       NaN                 NaT
# 2007-05-03       NaN          NaN        NaN       NaN                 NaT
# 2007-05-04       NaN          NaN        NaN       NaN                 NaT
# 2007-05-05       NaN          NaN        NaN       NaN                 NaT
# 2007-05-06       NaN          NaN        NaN       NaN                 NaT
# 2007-05-07       NaN          NaN        NaN       NaN                 NaT
# 2007-05-08       NaN          NaN        NaN       NaN                 NaT
# 2007-05-09       NaN          NaN        NaN       NaN                 NaT
# 2007-05-10       NaN          NaN        NaN       NaN                 NaT
# 2007-05-11       NaN          NaN        NaN       NaN                 NaT
# 2007-05-12       NaN          NaN        NaN       NaN                 NaT
# 2007-05-13       NaN          NaN        NaN       NaN                 NaT
# 2007-05-14       NaN          NaN        NaN       NaN                 NaT
# 2007-05-15     29.82          1.7       27.0       9.2 1900-01-01 04:48:00
# 2007-05-16     30.09         13.0        4.0      13.4 1900-01-01 04:47:00
# 2007-05-17     30.12         11.7        7.0      11.9 1900-01-01 04:46:00
# 2007-05-18     30.05         10.4        8.0      10.8 1900-01-01 04:44:00
# 2007-05-19     30.10         11.7        7.0      12.0 1900-01-01 04:43:00
# 2007-05-20     30.29         14.4       11.0      15.0 1900-01-01 04:42:00
#
#                       Sunset_1 daylight_duration  Humidity    Year  Month  \
# Date
# 2007-05-01                 NaT               NaT       NaN     NaN    NaN
# 2007-05-02                 NaT               NaT       NaN     NaN    NaN
# 2007-05-03                 NaT               NaT       NaN     NaN    NaN
# 2007-05-04                 NaT               NaT       NaN     NaN    NaN
# 2007-05-05                 NaT               NaT       NaN     NaN    NaN
# 2007-05-06                 NaT               NaT       NaN     NaN    NaN
# 2007-05-07                 NaT               NaT       NaN     NaN    NaN
# 2007-05-08                 NaT               NaT       NaN     NaN    NaN
# 2007-05-09                 NaT               NaT       NaN     NaN    NaN
# 2007-05-10                 NaT               NaT       NaN     NaN    NaN
# 2007-05-11                 NaT               NaT       NaN     NaN    NaN
# 2007-05-12                 NaT               NaT       NaN     NaN    NaN
# 2007-05-13                 NaT               NaT       NaN     NaN    NaN
# 2007-05-14                 NaT               NaT       NaN     NaN    NaN
# 2007-05-15 1900-01-01 18:49:00   0 days 14:01:00     56.44  2007.0    5.0
# 2007-05-16 1900-01-01 18:50:00   0 days 14:03:00     71.20  2007.0    5.0
# 2007-05-17 1900-01-01 18:51:00   0 days 14:05:00     54.87  2007.0    5.0
# 2007-05-18 1900-01-01 18:52:00   0 days 14:08:00     53.08  2007.0    5.0
# 2007-05-19 1900-01-01 18:53:00   0 days 14:10:00     43.97  2007.0    5.0
# 2007-05-20 1900-01-01 18:55:00   0 days 14:13:00     33.10  2007.0    5.0
#
#             Week  DayOfWeek
# Date
# 2007-05-01   NaN        NaN
# 2007-05-02   NaN        NaN
# 2007-05-03   NaN        NaN
# 2007-05-04   NaN        NaN
# 2007-05-05   NaN        NaN
# 2007-05-06   NaN        NaN
# 2007-05-07   NaN        NaN
# 2007-05-08   NaN        NaN
# 2007-05-09   NaN        NaN
# 2007-05-10   NaN        NaN
# 2007-05-11   NaN        NaN
# 2007-05-12   NaN        NaN
# 2007-05-13   NaN        NaN
# 2007-05-14   NaN        NaN
# 2007-05-15  18.0        1.0
# 2007-05-16  18.0        2.0
# 2007-05-17  18.0        3.0
# 2007-05-18  18.0        4.0
# 2007-05-19  18.0        5.0
# 2007-05-20  18.0        6.0
#             index  Station  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# Date
# 2007-05-01    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-02    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-03    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-04    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-05    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-06    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-07    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-08    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-09    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-10    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-11    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-12    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-13    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-14    NaN      NaN   NaN   NaN   NaN     NaN       NaN      NaN   NaN
# 2007-05-15    1.0      2.0  84.0  52.0  68.0    15.0      51.0     57.0   0.0
# 2007-05-16    3.0      2.0  60.0  43.0  52.0    -2.0      42.0     47.0  13.0
# 2007-05-17    5.0      2.0  67.0  48.0  58.0     4.0      40.0     50.0   7.0
# 2007-05-18    7.0      2.0  78.0  51.0  65.0    11.0      42.0     50.0   7.0
# 2007-05-19    9.0      2.0  66.0  54.0  60.0     5.0      39.0     50.0   5.0
# 2007-05-20   11.0      2.0  68.0  52.0  60.0     5.0      30.0     46.0   5.0
#
#             Cool Sunrise Sunset CodeSum  SnowFall  PrecipTotal  StnPressure  \
# Date
# 2007-05-01   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-02   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-03   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-04   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-05   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-06   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-07   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-08   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-09   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-10   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-11   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-12   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-13   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-14   NaN    None   None    None       NaN          NaN          NaN
# 2007-05-15   3.0    0448   1849   Clear       0.0          0.0        29.18
# 2007-05-16   0.0    0447   1850   BR HZ       0.0          0.0        29.44
# 2007-05-17   0.0    0446   1851      HZ       0.0          0.0        29.46
# 2007-05-18   0.0    0444   1852   Clear       0.0          0.0        29.36
# 2007-05-19   0.0    0443   1853   Clear       0.0          0.0        29.46
# 2007-05-20   0.0    0442   1855   Clear       0.0          0.0        29.62
#
#             SeaLevel  ResultSpeed  ResultDir  AvgSpeed  30_yr_temp  \
# Date
# 2007-05-01       NaN          NaN        NaN       NaN         NaN
# 2007-05-02       NaN          NaN        NaN       NaN         NaN
# 2007-05-03       NaN          NaN        NaN       NaN         NaN
# 2007-05-04       NaN          NaN        NaN       NaN         NaN
# 2007-05-05       NaN          NaN        NaN       NaN         NaN
# 2007-05-06       NaN          NaN        NaN       NaN         NaN
# 2007-05-07       NaN          NaN        NaN       NaN         NaN
# 2007-05-08       NaN          NaN        NaN       NaN         NaN
# 2007-05-09       NaN          NaN        NaN       NaN         NaN
# 2007-05-10       NaN          NaN        NaN       NaN         NaN
# 2007-05-11       NaN          NaN        NaN       NaN         NaN
# 2007-05-12       NaN          NaN        NaN       NaN         NaN
# 2007-05-13       NaN          NaN        NaN       NaN         NaN
# 2007-05-14       NaN          NaN        NaN       NaN         NaN
# 2007-05-15     29.82          2.7       25.0       9.6        53.0
# 2007-05-16     30.08         13.3        2.0      13.4        54.0
# 2007-05-17     30.12         12.9        6.0      13.2        54.0
# 2007-05-18     30.04         10.1        7.0      10.4        54.0
# 2007-05-19     30.09         11.2        7.0      11.5        55.0
# 2007-05-20     30.28         13.8       10.0      14.5        55.0
#
#                      Sunrise_1            Sunset_1 daylight_duration  Humidity
# Date
# 2007-05-01                 NaT                 NaT               NaT       NaN
# 2007-05-02                 NaT                 NaT               NaT       NaN
# 2007-05-03                 NaT                 NaT               NaT       NaN
# 2007-05-04                 NaT                 NaT               NaT       NaN
# 2007-05-05                 NaT                 NaT               NaT       NaN
# 2007-05-06                 NaT                 NaT               NaT       NaN
# 2007-05-07                 NaT                 NaT               NaT       NaN
# 2007-05-08                 NaT                 NaT               NaT       NaN
# 2007-05-09                 NaT                 NaT               NaT       NaN
# 2007-05-10                 NaT                 NaT               NaT       NaN
# 2007-05-11                 NaT                 NaT               NaT       NaN
# 2007-05-12                 NaT                 NaT               NaT       NaN
# 2007-05-13                 NaT                 NaT               NaT       NaN
# 2007-05-14                 NaT                 NaT               NaT       NaN
# 2007-05-15 1900-01-01 04:48:00 1900-01-01 18:49:00   0 days 14:01:00     54.53
# 2007-05-16 1900-01-01 04:47:00 1900-01-01 18:50:00   0 days 14:03:00     68.61
# 2007-05-17 1900-01-01 04:46:00 1900-01-01 18:51:00   0 days 14:05:00     51.06
# 2007-05-18 1900-01-01 04:44:00 1900-01-01 18:52:00   0 days 14:08:00     43.07
# 2007-05-19 1900-01-01 04:43:00 1900-01-01 18:53:00   0 days 14:10:00     45.72
# 2007-05-20 1900-01-01 04:42:00 1900-01-01 18:55:00   0 days 14:13:00     31.94

# %%
# drop all NaN columns
df_weather_shifted_1.dropna(inplace = True)
df_weather_shifted_2.dropna(inplace = True)

# %%
# reset index for df_weather_shifted_1 and 2
df_weather_shifted_1.reset_index(inplace = True)
df_weather_shifted_2.reset_index(inplace = True)

# %%
display(df_weather_shifted_1.info())
display(df_weather_shifted_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1458 non-null   datetime64[ns]
#  1   index              1458 non-null   float64
#  2   Station            1458 non-null   float64
#  3   Tmax               1458 non-null   float64
#  4   Tmin               1458 non-null   float64
#  5   Tavg               1458 non-null   float64
#  6   Depart             1458 non-null   float64
#  7   DewPoint           1458 non-null   float64
#  8   WetBulb            1458 non-null   float64
#  9   Heat               1458 non-null   float64
#  10  Cool               1458 non-null   float64
#  11  Sunrise            1458 non-null   object
#  12  Sunset             1458 non-null   object
#  13  CodeSum            1458 non-null   object
#  14  SnowFall           1458 non-null   float64
#  15  PrecipTotal        1458 non-null   float64
#  16  StnPressure        1458 non-null   float64
#  17  SeaLevel           1458 non-null   float64
#  18  ResultSpeed        1458 non-null   float64
#  19  ResultDir          1458 non-null   float64
#  20  AvgSpeed           1458 non-null   float64
#  21  Sunrise_1          1458 non-null   datetime64[ns]
#  22  Sunset_1           1458 non-null   datetime64[ns]
#  23  daylight_duration  1458 non-null   timedelta64[ns]
#  24  Humidity           1458 non-null   float64
#  25  Year               1458 non-null   float64
#  26  Month              1458 non-null   float64
#  27  Week               1458 non-null   float64
#  28  DayOfWeek          1458 non-null   float64
# dtypes: datetime64[ns](3), float64(22), object(3), timedelta64[ns](1)
# memory usage: 330.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1458 non-null   datetime64[ns]
#  1   index              1458 non-null   float64
#  2   Station            1458 non-null   float64
#  3   Tmax               1458 non-null   float64
#  4   Tmin               1458 non-null   float64
#  5   Tavg               1458 non-null   float64
#  6   Depart             1458 non-null   float64
#  7   DewPoint           1458 non-null   float64
#  8   WetBulb            1458 non-null   float64
#  9   Heat               1458 non-null   float64
#  10  Cool               1458 non-null   float64
#  11  Sunrise            1458 non-null   object
#  12  Sunset             1458 non-null   object
#  13  CodeSum            1458 non-null   object
#  14  SnowFall           1458 non-null   float64
#  15  PrecipTotal        1458 non-null   float64
#  16  StnPressure        1458 non-null   float64
#  17  SeaLevel           1458 non-null   float64
#  18  ResultSpeed        1458 non-null   float64
#  19  ResultDir          1458 non-null   float64
#  20  AvgSpeed           1458 non-null   float64
#  21  30_yr_temp         1458 non-null   float64
#  22  Sunrise_1          1458 non-null   datetime64[ns]
#  23  Sunset_1           1458 non-null   datetime64[ns]
#  24  daylight_duration  1458 non-null   timedelta64[ns]
#  25  Humidity           1458 non-null   float64
# dtypes: datetime64[ns](3), float64(19), object(3), timedelta64[ns](1)
# memory usage: 296.3+ KB
# None

# %% [markdown]
# ##### Merging Station 1 and 2 datasets

# %%
df_weather_final = df_weather_shifted_1.drop("index",axis=1).append(df_weather_shifted_2.drop(["30_yr_temp",'index'],axis=1))
df_weather_final = df_weather_final.sort_index()
df_weather_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2916 entries, 0 to 1457
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2916 non-null   datetime64[ns]
#  1   Station            2916 non-null   float64
#  2   Tmax               2916 non-null   float64
#  3   Tmin               2916 non-null   float64
#  4   Tavg               2916 non-null   float64
#  5   Depart             2916 non-null   float64
#  6   DewPoint           2916 non-null   float64
#  7   WetBulb            2916 non-null   float64
#  8   Heat               2916 non-null   float64
#  9   Cool               2916 non-null   float64
#  10  Sunrise            2916 non-null   object
#  11  Sunset             2916 non-null   object
#  12  CodeSum            2916 non-null   object
#  13  SnowFall           2916 non-null   float64
#  14  PrecipTotal        2916 non-null   float64
#  15  StnPressure        2916 non-null   float64
#  16  SeaLevel           2916 non-null   float64
#  17  ResultSpeed        2916 non-null   float64
#  18  ResultDir          2916 non-null   float64
#  19  AvgSpeed           2916 non-null   float64
#  20  Sunrise_1          2916 non-null   datetime64[ns]
#  21  Sunset_1           2916 non-null   datetime64[ns]
#  22  daylight_duration  2916 non-null   timedelta64[ns]
#  23  Humidity           2916 non-null   float64
#  24  Year               1458 non-null   float64
#  25  Month              1458 non-null   float64
#  26  Week               1458 non-null   float64
#  27  DayOfWeek          1458 non-null   float64
# dtypes: datetime64[ns](3), float64(21), object(3), timedelta64[ns](1)
# memory usage: 660.7+ KB

# %% [markdown]
# ### Merge with df_train

# %%
df_train_final = df_train.drop(["Address","Block","Street","AddressNumberAndStreet"],axis =1)

# %%
# creating Station column for df_train
df_train_final["Station"] = df_train_final["Latitude"]
df_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             10506 non-null  datetime64[ns]
#  1   Species          10506 non-null  object
#  2   Trap             10506 non-null  object
#  3   Latitude         10506 non-null  float64
#  4   Longitude        10506 non-null  float64
#  5   AddressAccuracy  10506 non-null  int64
#  6   NumMosquitos     10506 non-null  int64
#  7   WnvPresent       10506 non-null  int64
#  8   Year             10506 non-null  int64
#  9   Month            10506 non-null  int64
#  10  Week             10506 non-null  int64
#  11  DayOfWeek        10506 non-null  int64
#  12  Station          10506 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# creating Station column for df_train
for i in range(0,len(df_train_final)):
    if df_train_final.iloc[i,3] >= 41.87548:
        df_train_final.iloc[i,12] = 1
    else:
        df_train_final.iloc[i,12] = 2

# %%
df_train_final.groupby("Station").Latitude.count()
# Out:
# Station
# 1.0    4679
# 2.0    5827
# Name: Latitude, dtype: int64

# %%
#merging datasets
df_merged = pd.merge(df_train_final,df_weather_final, on = ["Date","Station"])

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 10505
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10506 non-null  datetime64[ns]
#  1   Species            10506 non-null  object
#  2   Trap               10506 non-null  object
#  3   Latitude           10506 non-null  float64
#  4   Longitude          10506 non-null  float64
#  5   AddressAccuracy    10506 non-null  int64
#  6   NumMosquitos       10506 non-null  int64
#  7   WnvPresent         10506 non-null  int64
#  8   Year_x             10506 non-null  int64
#  9   Month_x            10506 non-null  int64
#  10  Week_x             10506 non-null  int64
#  11  DayOfWeek_x        10506 non-null  int64
#  12  Station            10506 non-null  float64
#  13  Tmax               10506 non-null  float64
#  14  Tmin               10506 non-null  float64
#  15  Tavg               10506 non-null  float64
#  16  Depart             10506 non-null  float64
#  17  DewPoint           10506 non-null  float64
#  18  WetBulb            10506 non-null  float64
#  19  Heat               10506 non-null  float64
#  20  Cool               10506 non-null  float64
#  21  Sunrise            10506 non-null  object
#  22  Sunset             10506 non-null  object
#  23  CodeSum            10506 non-null  object
#  24  SnowFall           10506 non-null  float64
#  25  PrecipTotal        10506 non-null  float64
#  26  StnPressure        10506 non-null  float64
#  27  SeaLevel           10506 non-null  float64
#  28  ResultSpeed        10506 non-null  float64
#  29  ResultDir          10506 non-null  float64
#  30  AvgSpeed           10506 non-null  float64
#  31  Sunrise_1          10506 non-null  datetime64[ns]
#  32  Sunset_1           10506 non-null  datetime64[ns]
#  33  daylight_duration  10506 non-null  timedelta64[ns]
#  34  Humidity           10506 non-null  float64
#  35  Year_y             4679 non-null   float64
#  36  Month_y            4679 non-null   float64
#  37  Week_y             4679 non-null   float64
#  38  DayOfWeek_y        4679 non-null   float64
# dtypes: datetime64[ns](3), float64(23), int64(7), object(5), timedelta64[ns](1)
# memory usage: 3.2+ MB

# %%
df_merged.head()
# Out:
#         Date                 Species  Trap   Latitude  Longitude  \
# 0 2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1 2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2 2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 3 2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 4 2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
#
#    AddressAccuracy  NumMosquitos  WnvPresent  Year_x  Month_x  Week_x  \
# 0                9             1           0    2007        5      22
# 1                9             1           0    2007        5      22
# 2                9             1           0    2007        5      22
# 3                8             1           0    2007        5      22
# 4                8             4           0    2007        5      22
#
#    DayOfWeek_x  Station  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 0            1      1.0  80.0  57.0  69.0    11.0      56.0     61.0   0.0
# 1            1      1.0  80.0  57.0  69.0    11.0      56.0     61.0   0.0
# 2            1      1.0  80.0  57.0  69.0    11.0      56.0     61.0   0.0
# 3            1      1.0  80.0  57.0  69.0    11.0      56.0     61.0   0.0
# 4            1      1.0  80.0  57.0  69.0    11.0      56.0     61.0   0.0
#
#    Cool Sunrise Sunset CodeSum  SnowFall  PrecipTotal  StnPressure  SeaLevel  \
# 0   4.0    0432   1904   RA BR       0.0         0.38        29.13     29.84
# 1   4.0    0432   1904   RA BR       0.0         0.38        29.13     29.84
# 2   4.0    0432   1904   RA BR       0.0         0.38        29.13     29.84
# 3   4.0    0432   1904   RA BR       0.0         0.38        29.13     29.84
# 4   4.0    0432   1904   RA BR       0.0         0.38        29.13     29.84
#
#    ResultSpeed  ResultDir  AvgSpeed           Sunrise_1            Sunset_1  \
# 0          8.1       27.0      12.3 1900-01-01 04:32:00 1900-01-01 19:04:00
# 1          8.1       27.0      12.3 1900-01-01 04:32:00 1900-01-01 19:04:00
# 2          8.1       27.0      12.3 1900-01-01 04:32:00 1900-01-01 19:04:00
# 3          8.1       27.0      12.3 1900-01-01 04:32:00 1900-01-01 19:04:00
# 4          8.1       27.0      12.3 1900-01-01 04:32:00 1900-01-01 19:04:00
#
#   daylight_duration  Humidity  Year_y  Month_y  Week_y  DayOfWeek_y
# 0   0 days 14:32:00     63.27  2007.0      5.0    20.0          1.0
# 1   0 days 14:32:00     63.27  2007.0      5.0    20.0          1.0
# 2   0 days 14:32:00     63.27  2007.0      5.0    20.0          1.0
# 3   0 days 14:32:00     63.27  2007.0      5.0    20.0          1.0
# 4   0 days 14:32:00     63.27  2007.0      5.0    20.0          1.0

# %% [markdown]
# ### Merge with df_test

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116293 entries, 0 to 116292
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      116293 non-null  int64
#  1   Date                    116293 non-null  object
#  2   Address                 116293 non-null  object
#  3   Species                 116293 non-null  object
#  4   Block                   116293 non-null  int64
#  5   Street                  116293 non-null  object
#  6   Trap                    116293 non-null  object
#  7   AddressNumberAndStreet  116293 non-null  object
#  8   Latitude                116293 non-null  float64
#  9   Longitude               116293 non-null  float64
#  10  AddressAccuracy         116293 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 9.8+ MB

# %%
df_test_final = df_test.drop(["Id","Address","Block","Street","AddressNumberAndStreet"],axis =1)

# %%
df_test_final["Date"] = pd.to_datetime(df_test_final["Date"])

# %%
display(df_test_final.groupby("Species").Date.count())
# Out:
# Species
# CULEX ERRATICUS           14345
# CULEX PIPIENS             14521
# CULEX PIPIENS/RESTUANS    15359
# CULEX RESTUANS            14670
# CULEX SALINARIUS          14355
# CULEX TARSALIS            14347
# CULEX TERRITANS           14351
# UNSPECIFIED CULEX         14345
# Name: Date, dtype: int64

# %%
# creating Station column for df_train
df_test_final["Station"] = df_test_final["Latitude"]
df_test_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116293 entries, 0 to 116292
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             116293 non-null  datetime64[ns]
#  1   Species          116293 non-null  object
#  2   Trap             116293 non-null  object
#  3   Latitude         116293 non-null  float64
#  4   Longitude        116293 non-null  float64
#  5   AddressAccuracy  116293 non-null  int64
#  6   Station          116293 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 6.2+ MB

# %%
# creating Station column for df_train
for i in range(0,len(df_test_final)):
    if df_test_final.iloc[i,3] >= 41.87548:
        df_test_final.iloc[i,6] = 1
    else:
        df_test_final.iloc[i,6] = 2

# %%
df_test_final.groupby("Station").Latitude.count()
# Out:
# Station
# 1.0    52952
# 2.0    63341
# Name: Latitude, dtype: int64

# %%
df_test_final
# Out:
#              Date                 Species   Trap   Latitude  Longitude  \
# 0      2008-06-11  CULEX PIPIENS/RESTUANS   T002  41.954690 -87.800991
# 1      2008-06-11          CULEX RESTUANS   T002  41.954690 -87.800991
# 2      2008-06-11           CULEX PIPIENS   T002  41.954690 -87.800991
# 3      2008-06-11        CULEX SALINARIUS   T002  41.954690 -87.800991
# 4      2008-06-11         CULEX TERRITANS   T002  41.954690 -87.800991
# ...           ...                     ...    ...        ...        ...
# 116288 2014-10-02        CULEX SALINARIUS  T054C  41.925652 -87.633590
# 116289 2014-10-02         CULEX TERRITANS  T054C  41.925652 -87.633590
# 116290 2014-10-02          CULEX TARSALIS  T054C  41.925652 -87.633590
# 116291 2014-10-02       UNSPECIFIED CULEX  T054C  41.925652 -87.633590
# 116292 2014-10-02         CULEX ERRATICUS  T054C  41.925652 -87.633590
#
#         AddressAccuracy  Station
# 0                     9      1.0
# 1                     9      1.0
# 2                     9      1.0
# 3                     9      1.0
# 4                     9      1.0
# ...                 ...      ...
# 116288                8      1.0
# 116289                8      1.0
# 116290                8      1.0
# 116291                8      1.0
# 116292                8      1.0
#
# [116293 rows x 7 columns]

# %%
#merging datasets
df_merged_test = pd.merge(df_test_final,df_weather_final, on = ["Date","Station"])

# %%
df_merged_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116293 entries, 0 to 116292
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               116293 non-null  datetime64[ns]
#  1   Species            116293 non-null  object
#  2   Trap               116293 non-null  object
#  3   Latitude           116293 non-null  float64
#  4   Longitude          116293 non-null  float64
#  5   AddressAccuracy    116293 non-null  int64
#  6   Station            116293 non-null  float64
#  7   Tmax               116293 non-null  float64
#  8   Tmin               116293 non-null  float64
#  9   Tavg               116293 non-null  float64
#  10  Depart             116293 non-null  float64
#  11  DewPoint           116293 non-null  float64
#  12  WetBulb            116293 non-null  float64
#  13  Heat               116293 non-null  float64
#  14  Cool               116293 non-null  float64
#  15  Sunrise            116293 non-null  object
#  16  Sunset             116293 non-null  object
#  17  CodeSum            116293 non-null  object
#  18  SnowFall           116293 non-null  float64
#  19  PrecipTotal        116293 non-null  float64
#  20  StnPressure        116293 non-null  float64
#  21  SeaLevel           116293 non-null  float64
#  22  ResultSpeed        116293 non-null  float64
#  23  ResultDir          116293 non-null  float64
#  24  AvgSpeed           116293 non-null  float64
#  25  Sunrise_1          116293 non-null  datetime64[ns]
#  26  Sunset_1           116293 non-null  datetime64[ns]
#  27  daylight_duration  116293 non-null  timedelta64[ns]
#  28  Humidity           116293 non-null  float64
#  29  Year               52952 non-null   float64
#  30  Month              52952 non-null   float64
#  31  Week               52952 non-null   float64
#  32  DayOfWeek          52952 non-null   float64
# dtypes: datetime64[ns](3), float64(23), int64(1), object(5), timedelta64[ns](1)
# memory usage: 30.2+ MB

# %%
# Export dataset
df_merged_test.to_csv('../assets/df_merge_test.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Dataset: `train.csv`

# %%
# set datetime column to be the index for df_train_final
df_train_final.set_index('Date', inplace=True)

# %%
df_train_final.head()
# Out:
#                            Species  Trap   Latitude  Longitude  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
#
#             AddressAccuracy  NumMosquitos  WnvPresent  Year  Month  Week  \
# Date
# 2007-05-29                9             1           0  2007      5    22
# 2007-05-29                9             1           0  2007      5    22
# 2007-05-29                9             1           0  2007      5    22
# 2007-05-29                8             1           0  2007      5    22
# 2007-05-29                8             4           0  2007      5    22
#
#             DayOfWeek  Station
# Date
# 2007-05-29          1      1.0
# 2007-05-29          1      1.0
# 2007-05-29          1      1.0
# 2007-05-29          1      1.0
# 2007-05-29          1      1.0

# %% [markdown]
# ##### Types of species and WNV breakdown

# %%
df_train_final["NumMosquitos"].sum()
# Out:
# 135039

# %%
# for mosquitoes with West Nile Virus (Wnv)
df_train_final_1 = df_train_final[df_train_final["WnvPresent"]==1]
df_species_1 = pd.DataFrame(df_train_final_1.groupby("Species").NumMosquitos.sum())
df_species_1["Wnv"] = "With WNV"
df_species_1.sort_values("NumMosquitos",ascending = False)
# Out:
#                         NumMosquitos       Wnv
# Species
# CULEX PIPIENS/RESTUANS          7123  With WNV
# CULEX PIPIENS                   6729  With WNV
# CULEX RESTUANS                   667  With WNV

# %%
# for mosquitoes without West Nile Virus (Wnv)
df_train_final_0 = df_train_final[df_train_final["WnvPresent"]==0]
df_species_0 = pd.DataFrame(df_train_final_0.groupby("Species").NumMosquitos.sum())
df_species_0["Wnv"] = "Without WNV"
df_species_0.sort_values("NumMosquitos",ascending = False)
# Out:
#                         NumMosquitos          Wnv
# Species
# CULEX PIPIENS/RESTUANS         59145  Without WNV
# CULEX PIPIENS                  37942  Without WNV
# CULEX RESTUANS                 22764  Without WNV
# CULEX TERRITANS                  510  Without WNV
# CULEX SALINARIUS                 145  Without WNV
# CULEX ERRATICUS                    7  Without WNV
# CULEX TARSALIS                     7  Without WNV

# %%
# append both dataframes
df_species = df_species_1.append(df_species_0)
df_species
# Out:
#                         NumMosquitos          Wnv
# Species
# CULEX PIPIENS                   6729     With WNV
# CULEX PIPIENS/RESTUANS          7123     With WNV
# CULEX RESTUANS                   667     With WNV
# CULEX ERRATICUS                    7  Without WNV
# CULEX PIPIENS                  37942  Without WNV
# CULEX PIPIENS/RESTUANS         59145  Without WNV
# CULEX RESTUANS                 22764  Without WNV
# CULEX SALINARIUS                 145  Without WNV
# CULEX TARSALIS                     7  Without WNV
# CULEX TERRITANS                  510  Without WNV

# %%
# Mosquito species with/without WNV
plt.figure(figsize =(15,6))
plt.xticks(rotation=20)
sns.barplot(data=df_species, x=df_species.index, y='NumMosquitos', hue='Wnv')
plt.title("Infection Status of Mosquitos Classified by Species", fontsize = 15, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Infection Status of Mosquitos Classified by Species')

# %% [markdown]
# - Main mosquito species carrying WNV are CULEX PIPENS and CULEX RESTUANS
# - More than 90% species of mosquito belong to CULEX PIPENS and CULEX RESTUANS

# %%
# number of mosquitoes by month
df_train_month_0 = df_train_final_0.resample('M').sum()
df_train_month_1 = df_train_final_1.resample('M').sum()

# %%
# Number of mosquitoes time trend (month):
fig, ax1 = plt.subplots(figsize=(12,8))
ax1.plot(df_train_month_0['NumMosquitos'],  color = 'blue')
ax2 = ax1.twinx()
ax2.plot(df_train_month_1['NumMosquitos'], color = "red")
ax1.set_ylim([0, 35000])
ax2.set_ylim([0, 35000])
plt.title("Mosquitoes Count Time Trend (Mnth)", fontsize = 20)
ax1.set_ylabel("Count of Mosquitoes", fontsize = 12)
ax2.set_ylabel("Count of Mosquitoes with WNV",fontsize = 12)
ax1.set_xlabel("Time", fontsize = 12)
ax1.legend([f'Count of Infected Mosquitos (2011)'])
ax2.legend([f'Count of Infected Mosquitos (2013)'])

# %% [markdown]
# - By week, sub plot by year data
# - compare to the spray data
# - include the spray dates by plotting against 1/0

# %%
df_train_final_1
# Out:
#                            Species  Trap   Latitude  Longitude  \
# Date
# 2007-07-18  CULEX PIPIENS/RESTUANS  T215  41.686398 -87.531635
# 2007-07-25  CULEX PIPIENS/RESTUANS  T115  41.673408 -87.599862
# 2007-07-25  CULEX PIPIENS/RESTUANS  T115  41.673408 -87.599862
# 2007-07-25           CULEX PIPIENS  T115  41.673408 -87.599862
# 2007-07-25           CULEX PIPIENS  T115  41.673408 -87.599862
# ...                            ...   ...        ...        ...
# 2013-09-19  CULEX PIPIENS/RESTUANS  T900  41.974689 -87.890615
# 2013-09-26           CULEX PIPIENS  T003  41.964242 -87.757639
# 2013-09-26  CULEX PIPIENS/RESTUANS  T155  41.776156 -87.778927
# 2013-09-26  CULEX PIPIENS/RESTUANS  T900  41.974689 -87.890615
# 2013-09-26  CULEX PIPIENS/RESTUANS  T035  41.763733 -87.742302
#
#             AddressAccuracy  NumMosquitos  WnvPresent  Year  Month  Week  \
# Date
# 2007-07-18                8            50           1  2007      7    29
# 2007-07-25                5            50           1  2007      7    30
# 2007-07-25                5            50           1  2007      7    30
# 2007-07-25                5            50           1  2007      7    30
# 2007-07-25                5            50           1  2007      7    30
# ...                     ...           ...         ...   ...    ...   ...
# 2013-09-19                9            27           1  2013      9    38
# 2013-09-26                8             3           1  2013      9    39
# 2013-09-26                9             4           1  2013      9    39
# 2013-09-26                9            39           1  2013      9    39
# 2013-09-26                8             6           1  2013      9    39
#
#             DayOfWeek  Station
# Date
# 2007-07-18          2      2.0
# 2007-07-25          2      2.0
# 2007-07-25          2      2.0
# 2007-07-25          2      2.0
# 2007-07-25          2      2.0
# ...               ...      ...
# 2013-09-19          3      1.0
# 2013-09-26          3      1.0
# 2013-09-26          3      2.0
# 2013-09-26          3      1.0
# 2013-09-26          3      2.0
#
# [551 rows x 12 columns]

# %%
df_train_final_0[df_train_final_0["Year"]==2007].groupby(['Week'])['NumMosquitos'].sum()
# Out:
# Week
# 22      40
# 23     127
# 26     301
# 27     240
# 28    1103
# 29    1490
# 30    4066
# 31    9426
# 32    5846
# 33    9121
# 34    5397
# 35    4369
# 36    3686
# 37    1151
# 38    2122
# 39    1803
# 40    1353
# 41     333
# Name: NumMosquitos, dtype: int64

# %%
fig, ax = plt.subplots(2, figsize=(20,8), sharey=True, sharex=True, layout="constrained")
plt.suptitle("Non-infected Mosquito Count by Week (Before Spray Implementation)", fontsize = 15, fontweight='bold')
ax[0].plot(df_train_final_0[df_train_final_0["Year"]==2007].groupby(['Week'])['NumMosquitos'].sum(), color = 'blue')
ax[0].set_ylabel("Count of Mosquitoes", fontsize = 12)
ax[1].plot(df_train_final_0[df_train_final_0["Year"]==2009].groupby(['Week'])['NumMosquitos'].sum(), color = 'blue')
ax[1].set_xlabel("Week", fontsize = 12)
ax[1].set_ylabel("Count of Mosquitoes", fontsize = 12)
ax[0].legend([f'Count of Mosquitos (2007)'])
ax[1].legend([f'Count of Mosquitos (2009)'])
plt.xlim([21, 41])
# Out:
# (21.0, 41.0)

# %%
fig, ax = plt.subplots(2, figsize=(20,8), sharey=True, sharex=True, layout="constrained")
plt.suptitle("Infected Mosquito Count by Week (Before Spray Implementation)", fontsize = 15, fontweight='bold')
ax[0].plot(df_train_final_1[df_train_final_1["Year"]==2007].groupby(['Week'])['NumMosquitos'].sum(), color = 'red')
ax[0].set_ylabel("Count of Mosquitoes", fontsize = 12)
ax[1].plot(df_train_final_1[df_train_final_1["Year"]==2009].groupby(['Week'])['NumMosquitos'].sum(), color = 'red')
ax[1].set_xlabel("Week", fontsize = 12)
ax[1].set_ylabel("Count of Mosquitoes", fontsize = 12)
ax[0].legend([f'Count of Mosquitos (2007)'])
ax[1].legend([f'Count of Mosquitos (2009)'])
plt.xlim([21, 41])
# Out:
# (21.0, 41.0)

# %%
fig, ax = plt.subplots(2, figsize=(20,8), sharey=True, sharex=True, layout="constrained")
plt.suptitle("Non-infected Mosquito Count by Week (with Spray Info)", fontsize = 15, fontweight='bold')
ax[0].plot(df_train_final_0[df_train_final_0["Year"]==2011].groupby(['Week'])['NumMosquitos'].sum(), color = 'blue')
ax[0].set_ylabel("Count of Mosquitoes", fontsize = 12)
# ax[3].title.set_text("Year 2013")
ax[1].plot(df_train_final_0[df_train_final_0["Year"]==2013].groupby(['Week'])['NumMosquitos'].sum(), color = 'blue')
ax[1].set_xlabel("Week", fontsize = 12)
ax[1].set_ylabel("Count of Mosquitoes", fontsize = 12)
for week in df_spray[df_spray["Year"]==2011]['Week'].unique():
    ax[0].axvline(x=week, linestyle='--', color='grey', label='Spray Activated')
for week in df_spray[df_spray["Year"]==2013]['Week'].unique():
    ax[1].axvline(x=week, linestyle='--', color='grey', label='Spray Activated')
ax[0].legend([f'Count of Mosquitos (2011)', 'Spray Activated'])
ax[1].legend([f'Count of Mosquitos (2013)', 'Spray Activated'])
plt.xlim([21, 41])
# Out:
# (21.0, 41.0)

# %%
fig, ax = plt.subplots(2, figsize=(20,8), sharey=True, sharex=True, layout="constrained")
plt.suptitle("Infected Mosquito Count by Week (with Spray Info)", fontsize = 15, fontweight='bold')
ax[0].plot(df_train_final_1[df_train_final_1["Year"]==2011].groupby(['Week'])['NumMosquitos'].sum(), color = 'red')
ax[0].set_ylabel("Count of Mosquitoes", fontsize = 12)
ax[1].plot(df_train_final_1[df_train_final_1["Year"]==2013].groupby(['Week'])['NumMosquitos'].sum(), color = 'red')
ax[1].set_ylabel("Count of Mosquitoes", fontsize = 12)
for week in df_spray[df_spray["Year"]==2011]['Week'].unique():
    ax[0].axvline(x=week, linestyle='--', color='grey', label='Spray Activated')
for week in df_spray[df_spray["Year"]==2013]['Week'].unique():
    ax[1].axvline(x=week, linestyle='--', color='grey', label='Spray Activated')
ax[0].legend([f'Count of Infected Mosquitos (2011)', 'Spray Activated'])
ax[1].legend([f'Count of Infected Mosquitos (2013)', 'Spray Activated'])
ax[1].set_xlabel("Week", fontsize = 12)
plt.xlim([21, 41])
# Out:
# (21.0, 41.0)

# %%
# number of mosquitoes by year
df_train_year_0 = df_train_final_0.resample('Y').sum()
df_train_year_1 = df_train_final_1.resample('Y').sum()

# append both datasets together
df_train_year = df_train_year_0.append(df_train_year_1)
df_train_year
# Out:
#                  Latitude      Longitude  AddressAccuracy  NumMosquitos  \
# Date
# 2007-12-31  149478.204330 -313410.884667            26705         51974
# 2008-12-31       0.000000       0.000000                0             0
# 2009-12-31   93339.780567 -195616.352542            17857         20708
# 2010-12-31       0.000000       0.000000                0             0
# 2011-12-31   83593.351843 -175176.448892            15936         17606
# 2012-12-31       0.000000       0.000000                0             0
# 2013-12-31   90109.627955 -188835.258036            17318         30232
# 2007-12-31    9865.560256  -20691.767390             1728          6714
# 2008-12-31       0.000000       0.000000                0             0
# 2009-12-31     795.353659   -1667.515920              151           400
# 2010-12-31       0.000000       0.000000                0             0
# 2011-12-31    2389.535292   -5005.302861              463          1193
# 2012-12-31       0.000000       0.000000                0             0
# 2013-12-31   10011.595476  -20971.702964             1994          6212
#
#             WnvPresent     Year  Month    Week  DayOfWeek  Station
# Date
# 2007-12-31           0  7175025  28768  117749       7050   5933.0
# 2008-12-31           0        0      0       0          0      0.0
# 2009-12-31           0  4480070  16300   68054       5972   3337.0
# 2010-12-31           0        0      0       0          0      0.0
# 2011-12-31           0  4015967  15103   62012       5993   2979.0
# 2012-12-31           0        0      0       0          0      0.0
# 2013-12-31           0  4333989  16158   66526       6928   3270.0
# 2007-12-31         236   473652   1914    7926        495    394.0
# 2008-12-31           0        0      0       0          0      0.0
# 2009-12-31          19    38171    152     653         32     27.0
# 2010-12-31           0        0      0       0          0      0.0
# 2011-12-31          57   114627    467    1911        188     69.0
# 2012-12-31           0        0      0       0          0      0.0
# 2013-12-31         239   481107   1956    8074        772    324.0

# %%
#drop even year columns without data
df_train_year.drop(["2008-12-31","2010-12-31","2012-12-31"], inplace = True)

# %%
for i in range(0,len(df_train_year)):
    if df_train_year.iloc[i,4] > 0:
        df_train_year.iloc[i,4] = "Yes"
    else:
        df_train_year.iloc[i,4] = "No"

df_train_year
# Out:
#                  Latitude      Longitude  AddressAccuracy  NumMosquitos  \
# Date
# 2007-12-31  149478.204330 -313410.884667            26705         51974
# 2009-12-31   93339.780567 -195616.352542            17857         20708
# 2011-12-31   83593.351843 -175176.448892            15936         17606
# 2013-12-31   90109.627955 -188835.258036            17318         30232
# 2007-12-31    9865.560256  -20691.767390             1728          6714
# 2009-12-31     795.353659   -1667.515920              151           400
# 2011-12-31    2389.535292   -5005.302861              463          1193
# 2013-12-31   10011.595476  -20971.702964             1994          6212
#
#            WnvPresent     Year  Month    Week  DayOfWeek  Station
# Date
# 2007-12-31         No  7175025  28768  117749       7050   5933.0
# 2009-12-31         No  4480070  16300   68054       5972   3337.0
# 2011-12-31         No  4015967  15103   62012       5993   2979.0
# 2013-12-31         No  4333989  16158   66526       6928   3270.0
# 2007-12-31        Yes   473652   1914    7926        495    394.0
# 2009-12-31        Yes    38171    152     653         32     27.0
# 2011-12-31        Yes   114627    467    1911        188     69.0
# 2013-12-31        Yes   481107   1956    8074        772    324.0

# %%
# Number of mosquitoes time trend (year):
plt.figure(figsize =(15,6))
sns.barplot(data=df_train_year, x=df_train_year.index, y='NumMosquitos', hue='WnvPresent')
plt.title("Mosquitoes Count Time Trend (Year)", fontsize = 15, fontweight='bold')
plt.xlabel("Year",fontsize = 15)
plt.ylabel("Count",fontsize = 15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# - Observe large decrease in mosquito count from 2007 to 2009 even though the spray efforts were from:2011-08-29 to:2013-09-05
# - Spray efforts done in 2011 and 2013, seems rather ineffective

# %% [markdown]
# ##### Location

# %%
# Top 15 locations with most Mosquitoes:
df_train_top = df_train_final.groupby("Trap").NumMosquitos.sum().sort_values(ascending = False).head(15)
df_train_top
# Out:
# Trap
# T115    21668
# T900    15386
# T138     9936
# T002     3710
# T128     3315
# T135     3122
# T103     2988
# T008     2668
# T212     2595
# T158     2575
# T903     2327
# T114     2161
# T225     2014
# T151     1969
# T009     1940
# Name: NumMosquitos, dtype: int64

# %%
# for mosquitoes without West Nile Virus (Wnv)
df_loc_0 = pd.DataFrame(df_train_final_0.groupby("Trap").NumMosquitos.sum())
df_loc_0["Wnv Present"] = "Yes"
df_loc_0.sort_values("NumMosquitos",ascending = False)
# Out:
#        NumMosquitos Wnv Present
# Trap
# T115          19790         Yes
# T900          13326         Yes
# T138           9177         Yes
# T002           3210         Yes
# T128           2833         Yes
# T135           2806         Yes
# T103           2715         Yes
# T212           2500         Yes
# T158           2389         Yes
# T008           2338         Yes
# T903           2103         Yes
# T114           2002         Yes
# T151           1826         Yes
# T225           1729         Yes
# T048           1724         Yes
# T009           1641         Yes
# T090           1585         Yes
# T030           1489         Yes
# T221           1424         Yes
# T031           1415         Yes
# T200           1321         Yes
# T159           1261         Yes
# T066           1202         Yes
# T094           1119         Yes
# T223           1096         Yes
# T227           1091         Yes
# T011           1084         Yes
# T086           1080         Yes
# T209           1010         Yes
# T065            969         Yes
# T003            966         Yes
# T047            933         Yes
# T012            915         Yes
# T054            885         Yes
# T074            879         Yes
# T013            877         Yes
# T028            863         Yes
# T102            859         Yes
# T073            816         Yes
# T082            787         Yes
# T226            768         Yes
# T215            750         Yes
# T061            666         Yes
# T144            663         Yes
# T160            652         Yes
# T016            630         Yes
# T046            616         Yes
# T062            611         Yes
# T063            599         Yes
# T033            595         Yes
# T220            574         Yes
# T027            565         Yes
# T095            535         Yes
# T230            532         Yes
# T228            521         Yes
# T233            477         Yes
# T155            452         Yes
# T069            422         Yes
# T080            416         Yes
# T235            416         Yes
# T147            415         Yes
# T096            413         Yes
# T231            409         Yes
# T152            390         Yes
# T145            377         Yes
# T218            371         Yes
# T236            365         Yes
# T089            354         Yes
# T039            340         Yes
# T079            317         Yes
# T083            313         Yes
# T222            291         Yes
# T232            281         Yes
# T224            272         Yes
# T035            271         Yes
# T045            264         Yes
# T049            259         Yes
# T014            257         Yes
# T153            256         Yes
# T100            239         Yes
# T017            233         Yes
# T148            211         Yes
# T043            193         Yes
# T085            181         Yes
# T067            181         Yes
# T081            177         Yes
# T037            168         Yes
# T154            162         Yes
# T099            138         Yes
# T091            128         Yes
# T161            126         Yes
# T088            125         Yes
# T015            122         Yes
# T018            121         Yes
# T097            119         Yes
# T146            114         Yes
# T092            114         Yes
# T054C           100         Yes
# T143             87         Yes
# T084             84         Yes
# T107             79         Yes
# T007             77         Yes
# T019             72         Yes
# T025             72         Yes
# T129             72         Yes
# T077             69         Yes
# T050             68         Yes
# T070             67         Yes
# T071             65         Yes
# T206             65         Yes
# T162             63         Yes
# T006             61         Yes
# T004             59         Yes
# T150             56         Yes
# T156             53         Yes
# T075             52         Yes
# T034             52         Yes
# T219             50         Yes
# T142             49         Yes
# T036             47         Yes
# T157             47         Yes
# T094B            41         Yes
# T141             39         Yes
# T044             36         Yes
# T238             34         Yes
# T005             33         Yes
# T051             33         Yes
# T229             28         Yes
# T076             25         Yes
# T001             25         Yes
# T060             23         Yes
# T072             19         Yes
# T237             18         Yes
# T078             17         Yes
# T149             15         Yes
# T040              6         Yes

# %%
# for mosquitoes with West Nile Virus (Wnv)
df_loc_1 = pd.DataFrame(df_train_final_1.groupby("Trap").NumMosquitos.sum())
df_loc_1["Wnv Present"] = "No"
df_loc_1.sort_values("NumMosquitos",ascending = False)
# Out:
#        NumMosquitos Wnv Present
# Trap
# T900           2060          No
# T115           1878          No
# T138            759          No
# T002            500          No
# T128            482          No
# T003            380          No
# T008            330          No
# T135            316          No
# T013            316          No
# T030            313          No
# T009            299          No
# T225            285          No
# T233            281          No
# T221            275          No
# T103            273          No
# T086            232          No
# T011            227          No
# T903            224          No
# T016            217          No
# T158            186          No
# T223            185          No
# T054            177          No
# T061            174          No
# T096            165          No
# T114            159          No
# T028            157          No
# T066            154          No
# T151            143          No
# T143            143          No
# T235            141          No
# T031            128          No
# T228            122          No
# T231            112          No
# T230            112          No
# T159            110          No
# T065            107          No
# T014            107          No
# T082            105          No
# T209            103          No
# T215            102          No
# T027            101          No
# T090            100          No
# T212             95          No
# T227             88          No
# T045             87          No
# T033             85          No
# T226             80          No
# T155             78          No
# T094             78          No
# T147             74          No
# T048             72          No
# T039             64          No
# T047             64          No
# T095             58          No
# T220             57          No
# T015             47          No
# T200             47          No
# T006             46          No
# T054C            45          No
# T080             44          No
# T074             42          No
# T035             38          No
# T012             37          No
# T073             36          No
# T081             30          No
# T154             26          No
# T144             25          No
# T145             25          No
# T218             24          No
# T083             23          No
# T070             23          No
# T089             20          No
# T079             18          No
# T005             17          No
# T069             17          No
# T067             16          No
# T160             14          No
# T224             12          No
# T062             12          No
# T236             10          No
# T097             10          No
# T222              9          No
# T142              9          No
# T063              8          No
# T156              8          No
# T152              8          No
# T091              7          No
# T162              7          No
# T107              7          No
# T084              7          No
# T102              6          No
# T232              5          No
# T036              5          No
# T085              4          No
# T037              3          No
# T077              1          No
# T049              1          No

# %%
# append both dataframes
df_loc = df_loc_1.append(df_loc_0)
df_loc
# Out:
#       NumMosquitos Wnv Present
# Trap
# T002           500          No
# T003           380          No
# T005            17          No
# T006            46          No
# T008           330          No
# ...            ...         ...
# T236           365         Yes
# T237            18         Yes
# T238            34         Yes
# T900         13326         Yes
# T903          2103         Yes
#
# [233 rows x 2 columns]

# %%
# filter out to top 15 locations with most mosquitoes
df_loc_filter = df_loc.loc[['T115', 'T900', 'T138', 'T002', 'T128', 'T135', 'T103', 'T008', 'T212',
       'T158', 'T903', 'T114', 'T225', 'T151', 'T009'],:]

# %%
# Mosquito counts with/without WNV for locations in top 15 
plt.figure(figsize =(15,6))
sns.barplot(data=df_loc_filter, x=df_loc_filter.index, y='NumMosquitos', hue='Wnv Present')
plt.title("Overall Mosquito Count for Top 15 locations", fontsize = 15, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Overall Mosquito Count for Top 15 locations')

# %% [markdown]
# Top 5 locations with most overall mosquitoes over the years include
# - T115 (1200 S DOTY AVE, Chicago, IL)
# - T900 (1000 W OHARE AIRPORT, Chicago, IL)
# - T138 (1000 S STONY ISLAND AVE, Chicago, IL)
# - T002 (4100 N OAK PARK AVE, Chicago, IL)
# - T128 (2400 E 105TH ST, Chicago, IL)
#
# Yanda - find location on map

# %% [markdown]
# ##### Location by year

# %%
# group data by year and trap
df_train_grp = df_train_final.groupby([df_train_final.index.year,"Trap"]).agg(
    NumMosquitos = ("NumMosquitos", "sum"),
    WnvPresent = ("WnvPresent","mean"))

# group data by year
df_train_grp_year = df_train_final.groupby([df_train_final.index.year]).agg(
    NumMosquitos = ("NumMosquitos", "sum"),
    WnvPresent = ("WnvPresent","mean"))

display(df_train_grp)
display(df_train_grp_year)
# Out:
#            NumMosquitos  WnvPresent
# Date Trap
# 2007 T001            25    0.000000
#      T002           740    0.163265
#      T003           214    0.133333
#      T004            59    0.000000
#      T005            50    0.142857
# ...                 ...         ...
# 2013 T233           665    0.205882
#      T235           395    0.225806
#      T236           358    0.037037
#      T900          5689    0.193277
#      T903           194    0.000000
#
# [343 rows x 2 columns]
#       NumMosquitos  WnvPresent
# Date
# 2007         58688    0.061926
# 2009         21108    0.008448
# 2011         18799    0.027751
# 2013         36444    0.099916

# %%
# reset index
df_train_grp = df_train_grp.reset_index()

# %%
df_train_plot = df_train_grp[(df_train_grp["Trap"] == 'T115') | (df_train_grp["Trap"] == 'T900') | (df_train_grp["Trap"] == 'T138') | (df_train_grp["Trap"] == 'T002') | (df_train_grp["Trap"] == 'T128')]

# %%
df_train_plot
# Out:
#      Date  Trap  NumMosquitos  WnvPresent
# 1    2007  T002           740    0.163265
# 80   2007  T115         19134    0.088235
# 81   2007  T128          2532    0.132353
# 84   2007  T138          9321    0.068966
# 116  2009  T002           818    0.021739
# 157  2009  T115           529    0.000000
# 158  2009  T128            72    0.000000
# 160  2009  T138            94    0.000000
# 187  2009  T900          5488    0.007326
# 189  2011  T002           360    0.033333
# 232  2011  T115           871    0.023810
# 233  2011  T128           185    0.000000
# 235  2011  T138           242    0.000000
# 267  2011  T900          4209    0.075314
# 269  2013  T002          1792    0.133333
# 313  2013  T115          1134    0.088889
# 314  2013  T128           526    0.060606
# 316  2013  T138           279    0.000000
# 341  2013  T900          5689    0.193277

# %%
plt.figure(figsize =(15,6))
sns.barplot(data = df_train_grp_year, x = df_train_grp_year.index, y='NumMosquitos')
plt.title("Total No. of Mosquitos Captured by Year", fontsize = 15, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Total No. of Mosquitos Captured by Year')

# %% [markdown]
# - Observe that the spray efforts in 2011 and 2013 did not have a significant impact in reducing the mosquito counts for year 2011 to 2013. An increase in mosquitoes were observed, from 20,000 to ~40,000

# %%
plt.figure(figsize =(15,6))
sns.barplot(data=df_train_plot, x="Date", y='NumMosquitos', hue='Trap')
plt.title("5 Traps with Most Overall Number of Mosquitos (by Year)", fontsize = 15, fontweight='bold')
# Out:
# Text(0.5, 1.0, '5 Traps with Most Overall Number of Mosquitos (by Year)')

# %% [markdown]
# - Observe that the spray efforts in 2011 and 2013 did not have a significant impact in reducing the mosquito counts for T900 trap, which had a relatively similar mosquito count of ~4000 to ~6000 from 2009 to 2013.
# - Observe large decrease in mosquito count from 2007 to 2009 even though the spray efforts were in 2011 and 2013.

# %% [markdown]
# ### Dataset: `spray.csv`

# %%
df_spray.head()
# Out:
#                            Date        Time   Latitude  Longitude  Year  \
# datetime
# 2011-08-29 18:56:58  2011-08-29  6:56:58 PM  42.391623 -88.089163  2011
# 2011-08-29 18:57:08  2011-08-29  6:57:08 PM  42.391348 -88.089163  2011
# 2011-08-29 18:57:18  2011-08-29  6:57:18 PM  42.391022 -88.089157  2011
# 2011-08-29 18:57:28  2011-08-29  6:57:28 PM  42.390637 -88.089158  2011
# 2011-08-29 18:57:38  2011-08-29  6:57:38 PM  42.390410 -88.088858  2011
#
#                      Month  Week  DayOfWeek
# datetime
# 2011-08-29 18:56:58      8    35          0
# 2011-08-29 18:57:08      8    35          0
# 2011-08-29 18:57:18      8    35          0
# 2011-08-29 18:57:28      8    35          0
# 2011-08-29 18:57:38      8    35          0

# %%
# hist
df_spray_day = df_spray.resample("D").count()
df_spray_day
# Out:
#             Date  Time  Latitude  Longitude  Year  Month  Week  DayOfWeek
# datetime
# 2011-08-29    95    95        95         95    95     95    95         95
# 2011-08-30     0     0         0          0     0      0     0          0
# 2011-08-31     0     0         0          0     0      0     0          0
# 2011-09-01     0     0         0          0     0      0     0          0
# 2011-09-02     0     0         0          0     0      0     0          0
# ...          ...   ...       ...        ...   ...    ...   ...        ...
# 2013-09-01     0     0         0          0     0      0     0          0
# 2013-09-02     0     0         0          0     0      0     0          0
# 2013-09-03     0     0         0          0     0      0     0          0
# 2013-09-04     0     0         0          0     0      0     0          0
# 2013-09-05   924   924       924        924   924    924   924        924
#
# [739 rows x 8 columns]

# %%
df_spray_month = df_spray_day.resample("M").count()
df_spray_month
# Out:
#             Date  Time  Latitude  Longitude  Year  Month  Week  DayOfWeek
# datetime
# 2011-08-31     3     3         3          3     3      3     3          3
# 2011-09-30    30    30        30         30    30     30    30         30
# 2011-10-31    31    31        31         31    31     31    31         31
# 2011-11-30    30    30        30         30    30     30    30         30
# 2011-12-31    31    31        31         31    31     31    31         31
# 2012-01-31    31    31        31         31    31     31    31         31
# 2012-02-29    29    29        29         29    29     29    29         29
# 2012-03-31    31    31        31         31    31     31    31         31
# 2012-04-30    30    30        30         30    30     30    30         30
# 2012-05-31    31    31        31         31    31     31    31         31
# 2012-06-30    30    30        30         30    30     30    30         30
# 2012-07-31    31    31        31         31    31     31    31         31
# 2012-08-31    31    31        31         31    31     31    31         31
# 2012-09-30    30    30        30         30    30     30    30         30
# 2012-10-31    31    31        31         31    31     31    31         31
# 2012-11-30    30    30        30         30    30     30    30         30
# 2012-12-31    31    31        31         31    31     31    31         31
# 2013-01-31    31    31        31         31    31     31    31         31
# 2013-02-28    28    28        28         28    28     28    28         28
# 2013-03-31    31    31        31         31    31     31    31         31
# 2013-04-30    30    30        30         30    30     30    30         30
# 2013-05-31    31    31        31         31    31     31    31         31
# 2013-06-30    30    30        30         30    30     30    30         30
# 2013-07-31    31    31        31         31    31     31    31         31
# 2013-08-31    31    31        31         31    31     31    31         31
# 2013-09-30     5     5         5          5     5      5     5          5

# %% [markdown]
# ### Dataset: `weather.csv`

# %% [markdown]
# #### Temperature delta between stations

# %%
# cal delta between Temperature readings for station 1 and station 2
df_weather_1["Tmax_delta"] = df_weather_1["Tmax"]-df_weather_2["Tmax"]
df_weather_1["Tmin_delta"] = df_weather_1["Tmin"]-df_weather_2["Tmin"]
df_weather_1["Tavg_delta"] = df_weather_1["Tavg"]-df_weather_2["Tavg"]

# %%
plt.figure(figsize=(15,4))
plt.title("Tmax Delta Between Station 1 & 2", fontsize = 15, fontweight='bold')
plt.xlabel("Year",fontsize = 15)
plt.ylabel("Max Temperature Delta", fontsize = 15)
sns.boxplot(x ='Year' , y = 'Tmax_delta', data = df_weather_1)

plt.figure(figsize=(15,4))
plt.title("Tmin Delta Between Station 1 & 2", fontsize = 15, fontweight='bold')
plt.xlabel("Year",fontsize = 15)
plt.ylabel("Min Temperature Delta", fontsize = 15)
sns.boxplot(x ='Year' , y = 'Tmin_delta', data = df_weather_1)

plt.figure(figsize=(15,4))
plt.title("Tavg Delta Between Station 1 & 2", fontsize = 15, fontweight='bold')
plt.ylabel("Avg Temperature Delta")
plt.xlabel("Time")
sns.boxplot(x ='Year' , y = 'Tmin_delta', data = df_weather_1)
# Out:
# <AxesSubplot: title={'center': 'Tavg Delta Between Station 1 & 2'}, xlabel='Year', ylabel='Tmin_delta'>

# %% [markdown]
# - delta average temperature (Fahrenheit) is in the range of 5 to 10 (absolute value). delta of 10 degF = ~5.5 degC delta.
# - formula: Δ°C x 9/5= Δ°F
# - boxplots showed that no significant differences between Stations 1 & 2 --> readings from both stations are similar

# %% [markdown]
# ##### Time Trend

# %%
# Time period available
for i in range(2007,2014,2):
    print(f'{i} min : {df_merged[df_merged["Date"].dt.year == i]["Date"].min()}'
         f'{i} max : {df_merged[df_merged["Date"].dt.year == i]["Date"].max()}')
# Out:
# 2007 min : 2007-05-29 00:00:002007 max : 2007-10-09 00:00:00
# 2009 min : 2009-05-28 00:00:002009 max : 2009-10-01 00:00:00
# 2011 min : 2011-06-10 00:00:002011 max : 2011-09-30 00:00:00
# 2013 min : 2013-06-07 00:00:002013 max : 2013-09-26 00:00:00

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 10505
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10506 non-null  datetime64[ns]
#  1   Species            10506 non-null  object
#  2   Trap               10506 non-null  object
#  3   Latitude           10506 non-null  float64
#  4   Longitude          10506 non-null  float64
#  5   AddressAccuracy    10506 non-null  int64
#  6   NumMosquitos       10506 non-null  int64
#  7   WnvPresent         10506 non-null  int64
#  8   Year_x             10506 non-null  int64
#  9   Month_x            10506 non-null  int64
#  10  Week_x             10506 non-null  int64
#  11  DayOfWeek_x        10506 non-null  int64
#  12  Station            10506 non-null  float64
#  13  Tmax               10506 non-null  float64
#  14  Tmin               10506 non-null  float64
#  15  Tavg               10506 non-null  float64
#  16  Depart             10506 non-null  float64
#  17  DewPoint           10506 non-null  float64
#  18  WetBulb            10506 non-null  float64
#  19  Heat               10506 non-null  float64
#  20  Cool               10506 non-null  float64
#  21  Sunrise            10506 non-null  object
#  22  Sunset             10506 non-null  object
#  23  CodeSum            10506 non-null  object
#  24  SnowFall           10506 non-null  float64
#  25  PrecipTotal        10506 non-null  float64
#  26  StnPressure        10506 non-null  float64
#  27  SeaLevel           10506 non-null  float64
#  28  ResultSpeed        10506 non-null  float64
#  29  ResultDir          10506 non-null  float64
#  30  AvgSpeed           10506 non-null  float64
#  31  Sunrise_1          10506 non-null  datetime64[ns]
#  32  Sunset_1           10506 non-null  datetime64[ns]
#  33  daylight_duration  10506 non-null  timedelta64[ns]
#  34  Humidity           10506 non-null  float64
#  35  Year_y             4679 non-null   float64
#  36  Month_y            4679 non-null   float64
#  37  Week_y             4679 non-null   float64
#  38  DayOfWeek_y        4679 non-null   float64
# dtypes: datetime64[ns](3), float64(23), int64(7), object(5), timedelta64[ns](1)
# memory usage: 3.2+ MB

# %%
for i in df_merged.iloc[:,range(6,30)].columns:
    plt.figure(figsize=(12,8))
    sns.lineplot(data=df_merged, x=df_merged["Date"], y=df_merged[i], palette="rainbow")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[750], line 3
#       1 for i in df_merged.iloc[:,range(6,30)].columns:
#       2     plt.figure(figsize=(12,8))
# ----> 3     sns.lineplot(data=df_merged, x=df_merged["Date"], y=df_merged[i], palette="rainbow")
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:441, in _LinePlotter.plot(self, ax, kws)
#     438     grouped = sub_data.groupby(orient, sort=self.sort)
#     439     # Could pass as_index=False instead of reset_index,
#     440     # but that fails on a corner case with older pandas.
# --> 441     sub_data = grouped.apply(agg, other).reset_index()
#     442 else:
#     443     sub_data[f"{other}min"] = np.nan
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1549, in GroupBy.apply(self, func, *args, **kwargs)
#    1547 with option_context("mode.chained_assignment", None):
#    1548     try:
# -> 1549         result = self._python_apply_general(f, self._selected_obj)
#    1550     except TypeError:
#    1551         # gh-20949
#    1552         # try again, with .apply acting as a filtering
#    (...)
#    1556         # fails on *some* columns, e.g. a numeric operation
#    1557         # on a string grouper column
#    1559         with self._group_selection_context():
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1601, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1564 @final
#    1565 def _python_apply_general(
#    1566     self,
#    (...)
#    1571     is_agg: bool = False,
#    1572 ) -> NDFrameT:
#    1573     """
#    1574     Apply function f in python space
#    1575
#    (...)
#    1599         data after applying f
#    1600     """
# -> 1601     values, mutated = self.grouper.apply(f, data, self.axis)
#    1602     if not_indexed_same is None:
#    1603         not_indexed_same = mutated or self.mutated
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1532, in GroupBy.apply.<locals>.f(g)
#    1529 @wraps(func)
#    1530 def f(g):
#    1531     with np.errstate(all="ignore"):
# -> 1532         return func(g, *args, **kwargs)
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_statistics.py:513, in EstimateAggregator.__call__(self, data, var)
#     511 elif self.error_method == "ci":
#     512     units = data.get("units", None)
# --> 513     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
#     514     err_min, err_max = _percentile_interval(boots, self.error_level)
#     516 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File c:\Users\gyinh\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:96, in bootstrap(*args, **kwargs)
#      94 boot_dist = []
#      95 for i in range(int(n_boot)):
# ---> 96     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      97     sample = [a.take(resampler, axis=0) for a in args]
#      98     boot_dist.append(f(*sample, **func_kwargs))
#
# KeyboardInterrupt:

# %%
# drop snowfall since the period has no snow
df_merged.drop("SnowFall",axis = 1, inplace = True)

# %%
df_merged = df_merged.reset_index()

# %% [markdown]
# ### Heatplot Map

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              0 non-null      object
#  1   Date               0 non-null      datetime64[ns]
#  2   Species            0 non-null      object
#  3   Trap               0 non-null      object
#  4   Latitude           0 non-null      float64
#  5   Longitude          0 non-null      float64
#  6   AddressAccuracy    0 non-null      int64
#  7   NumMosquitos       0 non-null      int64
#  8   WnvPresent         0 non-null      int64
#  9   Year_x             0 non-null      int64
#  10  Month_x            0 non-null      int64
#  11  Week_x             0 non-null      int64
#  12  DayOfWeek_x        0 non-null      int64
#  13  Station            0 non-null      float64
#  14  Tmax               0 non-null      float64
#  15  Tmin               0 non-null      float64
#  16  Tavg               0 non-null      float64
#  17  Depart             0 non-null      float64
#  18  DewPoint           0 non-null      float64
#  19  WetBulb            0 non-null      float64
#  20  Heat               0 non-null      float64
#  21  Cool               0 non-null      float64
#  22  Sunrise            0 non-null      object
#  23  Sunset             0 non-null      object
#  24  CodeSum            0 non-null      object
#  25  PrecipTotal        0 non-null      float64
#  26  StnPressure        0 non-null      float64
#  27  SeaLevel           0 non-null      float64
#  28  ResultSpeed        0 non-null      float64
#  29  ResultDir          0 non-null      float64
#  30  AvgSpeed           0 non-null      float64
#  31  Sunrise_1          0 non-null      datetime64[ns]
#  32  Sunset_1           0 non-null      datetime64[ns]
#  33  daylight_duration  0 non-null      timedelta64[ns]
#  34  Humidity           0 non-null      float64
#  35  Year_y             0 non-null      float64
#  36  Month_y            0 non-null      float64
#  37  Week_y             0 non-null      float64
#  38  DayOfWeek_y        0 non-null      float64
# dtypes: datetime64[ns](3), float64(22), int64(7), object(6), timedelta64[ns](1)
# memory usage: 124.0+ bytes

# %%
#heatmap for non-object features
mask = np.zeros_like(df_merged.iloc[:,range(7,31)].corr())
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(20,20))
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
sns.heatmap(
    df_merged.iloc[:,range(7,31)].corr(),
    cmap='coolwarm',
    annot=True,
    fmt = ".2f",
    mask = mask,
    linewidth = 0.3)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Drop features with high colinearity >0.85
# - ResultSpeed (AvgSpeed)
# - StnPressure (SeaLevel)
# - Tmin, Tmax, DewPoint, WetBulb, Cool, (Tavg)

# %%
# drop features with high colinearity, and drop sunrise, sunset.
df_merged_final = df_merged.drop(["index","ResultSpeed","StnPressure","Tmin", "Tmax", "DewPoint", "WetBulb", "Cool", "Sunrise", "Sunset"],axis = 1)

# %%
df_merged_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               0 non-null      datetime64[ns]
#  1   Species            0 non-null      object
#  2   Trap               0 non-null      object
#  3   Latitude           0 non-null      float64
#  4   Longitude          0 non-null      float64
#  5   AddressAccuracy    0 non-null      int64
#  6   NumMosquitos       0 non-null      int64
#  7   WnvPresent         0 non-null      int64
#  8   Year_x             0 non-null      int64
#  9   Month_x            0 non-null      int64
#  10  Week_x             0 non-null      int64
#  11  DayOfWeek_x        0 non-null      int64
#  12  Station            0 non-null      float64
#  13  Tavg               0 non-null      float64
#  14  Depart             0 non-null      float64
#  15  Heat               0 non-null      float64
#  16  CodeSum            0 non-null      object
#  17  PrecipTotal        0 non-null      float64
#  18  SeaLevel           0 non-null      float64
#  19  ResultDir          0 non-null      float64
#  20  AvgSpeed           0 non-null      float64
#  21  Sunrise_1          0 non-null      datetime64[ns]
#  22  Sunset_1           0 non-null      datetime64[ns]
#  23  daylight_duration  0 non-null      timedelta64[ns]
#  24  Humidity           0 non-null      float64
#  25  Year_y             0 non-null      float64
#  26  Month_y            0 non-null      float64
#  27  Week_y             0 non-null      float64
#  28  DayOfWeek_y        0 non-null      float64
# dtypes: datetime64[ns](3), float64(15), int64(7), object(3), timedelta64[ns](1)
# memory usage: 124.0+ bytes

# %% [raw]
# for i in df_merged_final.iloc[:,range(6,20)].columns:
#     plt.figure(figsize=(12,8))
#     sns.pairplot(data = df_merged, y_vars=['NumMosquitos'], x_vars=i, kind='reg', plot_kws={'line_kws':{'color':'red'}})

# %%
# Export dataset
df_merged_final.to_csv('../assets/df_merge_final.csv', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8103834c-d9e3-438c-981d-c55551eaafe0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
