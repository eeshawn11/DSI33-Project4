       'T115', 'T138', 'T200', 'T206', 'T209', 'T212', 'T215', 'T107',
       'T128', 'T072', 'T078', 'T097', 'T099', 'T100', 'T102', 'T103',
       'T027', 'T156', 'T157', 'T221', 'T900', 'T903', 'T222', 'T223',
       'T225', 'T227', 'T224', 'T226', 'T229', 'T230', 'T228', 'T232',
       'T231', 'T235', 'T233', 'T236', 'T237', 'T238', 'T094B', 'T054C']

# %%
for value in params:
    df_name = 'df' + value
    df_name = loc_df[loc_df['Trap'] == value]
    print(f"{df_name.iloc[0]['Trap']} is located in {df_name.iloc[0]['Street']}")
# Out:
# T002 is located in  N OAK PARK AVE
# T007 is located in  N MANDELL AVE
# T015 is located in  W FOSTER AVE
# T045 is located in  W WEBSTER AVE
# T046 is located in  W GRAND AVE
# T048 is located in  W ROOSEVELT
# T049 is located in  W CHICAGO
# T050 is located in  N STAVE ST
# T054 is located in  N CANNON DR
# T086 is located in  W 113TH ST
# T091 is located in  S PEORIA ST
# T094 is located in  W 95TH ST
# T096 is located in  W 89TH ST
# T129 is located in  N STREETER DR
# T143 is located in  N OAK PARK AVE
# T148 is located in  N OAKLEY AVE
# T153 is located in  N LONG AVE
# T159 is located in  S CARPENTER ST
# T009 is located in  W HIGGINS AVE
# T011 is located in  N PITTSBURGH AVE
# T016 is located in  N OKETO AVE
# T019 is located in  N CALIFORNIA AVE
# T025 is located in  W BALMORAL AVE
# T028 is located in  N WESTERN AVE
# T031 is located in  S CENTRAL AVE
# T033 is located in  N HUMBOLDT DR
# T089 is located in  S VINCENNES
# T090 is located in  S ASHLAND AVE
# T092 is located in  S STATE ST
# T135 is located in  W 127TH PL
# T141 is located in  W AGATITE AVE
# T142 is located in  N AUSTIN AVE
# T145 is located in  N ASHLAND AVE OVERPASS
# T146 is located in  N RICHMOND ST
# T147 is located in  N FRANCISCO AVE
# T149 is located in  W GRANVILLE AVE
# T150 is located in  W FARWELL AVE
# T151 is located in   W ARMITAGE AVENUE
# T152 is located in  S MILLARD AVE
# T154 is located in  N LAWLER AVE
# T158 is located in  W 116TH ST
# T162 is located in  S DR MARTIN LUTHER KING JR DR
# T218 is located in  N KEDVALE AVE
# T220 is located in  N CAMPBELL AVE
# T001 is located in  N TRIPP AVE
# T003 is located in  N MILWAUKEE AVE
# T006 is located in  N AVONDALE AVE
# T008 is located in  N MOSELL AVE
# T012 is located in  N LEMONT AVE
# T034 is located in  S WESTERN AVE
# T037 is located in  W BELDEN AVE
# T040 is located in  S HAMLIN AVE
# T043 is located in  W 18TH ST
# T047 is located in  S CALIFORNIA
# T051 is located in  S THROOP
# T085 is located in  W 95TH ST
# T088 is located in  S CALIFORNIA AVE
# T161 is located in  S HOYNE AVE
# T219 is located in  W LELAND AVE
# T013 is located in  W FULLERTON AVE
# T014 is located in  W STRONG ST
# T018 is located in  W GREENLEAF AVE
# T030 is located in  N CENTRAL PARK DR
# T084 is located in  E 111TH ST
# T144 is located in  N RUTHERFORD AVE
# T160 is located in  S ARTESIAN AVE
# T005 is located in  W ROSCOE ST
# T017 is located in  W MONTROSE DR
# T044 is located in  E RANDOLPH ST
# T095 is located in  W 104TH ST
# T004 is located in  W SUNNYSIDE AVE
# T035 is located in  S HOYNE AVE
# T036 is located in  W 31ST ST
# T039 is located in  N PULASKI RD
# T060 is located in  W PERSHING RD
# T061 is located in  W 51ST ST
# T062 is located in  W 51ST ST
# T065 is located in  W 63RD ST
# T066 is located in  S KEDZIE AVE
# T067 is located in  S CICERO AVE
# T069 is located in  W 69TH ST
# T070 is located in  S NORDICA
# T071 is located in  S MELVINA AVE
# T073 is located in  E 67TH ST
# T074 is located in  S ASHLAND AVE
# T075 is located in  S CORNELL AVE
# T076 is located in  S DR MARTIN LUTHER KING JR DR
# T077 is located in  S STONY ISLAND AVE
# T079 is located in  S SOUTH SHORE DR
# T080 is located in  S EBERHART AVE
# T081 is located in  S DEARBORN ST
# T082 is located in  S UNION AVE
# T083 is located in  S CHICAGO AVE
# T114 is located in  S KOLMAR
# T155 is located in  W 64TH ST
# T063 is located in  S PULASKI RD
# T115 is located in  S DOTY AVE
# T138 is located in  S STONY ISLAND AVE
# T200 is located in  S TORRENCE AVE
# T206 is located in  S MACKINAW
# T209 is located in  S BRANDON
# T212 is located in  E 118TH ST
# T215 is located in  E 115TH ST
# T107 is located in  E 91ST ST
# T128 is located in  E 105TH ST
# T072 is located in  S KEDZIE AVE
# T078 is located in  S RACINE AVE
# T097 is located in  E 138TH ST
# T099 is located in  S MUSKEGON AVE
# T100 is located in  S AVENUE G
# T102 is located in  S COTTAGE GROVE
# T103 is located in  S AVENUE L
# T027 is located in  N PULASKI RD
# T156 is located in  S KILPATRICK AVE
# T157 is located in  W 37TH PL.
# T221 is located in  E 130TH ST
# T900 is located in  W OHARE AIRPORT
# T903 is located in  W OHARE
# T222 is located in  W MONTANA ST
# T223 is located in  N MONT CLARE AVE
# T225 is located in  S KOSTNER AVE
# T227 is located in  E 91ST PL
# T224 is located in  W ADDISON ST
# T226 is located in  W GARFIELD BLVD
# T229 is located in  S WALLACE ST
# T230 is located in  N LARAMIE AVE
# T228 is located in  N SPRINGFIELD AVE
# T232 is located in  N ASHLAND AVE
# T231 is located in  N RIDGE AVE
# T235 is located in  W 65TH ST
# T233 is located in  N HARLEM AVE
# T236 is located in  N MCCLELLAN AVE
# T237 is located in  W 85TH ST
# T238 is located in  W 77TH ST
# T094B is located in  S LONGWOOD DR
# T054C is located in  N CANNON DR

# %%
df.head()
# Out:
#          Date                 Species  Trap   Latitude  Longitude  \
# 0  2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1  2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 2  2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# 3  2007-05-29  CULEX PIPIENS/RESTUANS  T015  41.974089 -87.824812
# 4  2007-05-29          CULEX RESTUANS  T015  41.974089 -87.824812
#
#    AddressAccuracy  NumMosquitos  WnvPresent  Station  Tavg  ...  Heat  \
# 0                9             1           0      1.0  74.0  ...   0.0
# 1                9             1           0      1.0  74.0  ...   0.0
# 2                9             1           0      1.0  74.0  ...   0.0
# 3                8             1           0      1.0  74.0  ...   0.0
# 4                8             4           0      1.0  74.0  ...   0.0
#
#    CodeSum PrecipTotal  SeaLevel  ResultDir  AvgSpeed            Sunrise_1  \
# 0    BR HZ         0.0     30.11         18       6.5  1900-01-01 04:21:00
# 1    BR HZ         0.0     30.11         18       6.5  1900-01-01 04:21:00
# 2    BR HZ         0.0     30.11         18       6.5  1900-01-01 04:21:00
# 3    BR HZ         0.0     30.11         18       6.5  1900-01-01 04:21:00
# 4    BR HZ         0.0     30.11         18       6.5  1900-01-01 04:21:00
#
#               Sunset_1 daylight_duration Humidity
# 0  1900-01-01 19:17:00   0 days 14:56:00     57.4
# 1  1900-01-01 19:17:00   0 days 14:56:00     57.4
# 2  1900-01-01 19:17:00   0 days 14:56:00     57.4
# 3  1900-01-01 19:17:00   0 days 14:56:00     57.4
# 4  1900-01-01 19:17:00   0 days 14:56:00     57.4
#
# [5 rows x 21 columns]

# %%
spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
traps = df[['Longitude','Latitude']].drop_duplicates().values

# %%
traps.head()
# Out:
#    Longitude   Latitude
# 0 -87.800991  41.954690
# 2 -87.769279  41.994991
# 3 -87.824812  41.974089
# 5 -87.666455  41.921600
# 6 -87.654491  41.891118

# %%
plt.figure(figsize=(15,15))
plt.title('Map with Sprays')
plt.imshow(mapdata,
          cmap=plt.get_cmap('gray'),
          extent=bbox,
          );

plt.scatter(traps[:,0], traps[:,1], marker='D', alpha=1)

# %%
sprays = spray[['Longitude', 'Latitude']].drop_duplicates().values
bbox = (-88, -87.5, 41.6, 42.1)

# %%
plt.figure(figsize=(15,15))
plt.title('Map with Sprays')
plt.imshow(mapdata,
          cmap=plt.get_cmap('gray'),
          extent=bbox,
          );

plt.scatter(sprays[:,0], sprays[:,1], c='g', alpha=1)

# %%
plt.figure(figsize=(15,15))
plt.title('Map with Sprays')
plt.imshow(mapdata,
          cmap=plt.get_cmap('gray'),
          extent=bbox,
          );

plt.scatter(sprays[:,0], sprays[:,1], c='g', alpha=1)
plt.scatter(traps[:,0], traps[:,1], marker='D', alpha=1)

# %% [markdown]
# Currently pulling up data from all the years when spray data only is in 2011 and 2013. Isolate data series that are in the 2011 and 2013 periods.

# %%
date_traps = df[['Date','Longitude','Latitude']].drop_duplicates().values

# %%
date_traps['Year'], date_traps['Month'] = date_traps['Date'].dt.year, date_traps['Date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 date_traps['Year'], date_traps['Month'] = date_traps['Date'].dt.year, date_traps['Date'].dt.month
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# CULEX PIPENS and CULEX RESTUANS are the most common carriers of the WNV virus.

# %% [markdown]
# In the northeastern United States, Culex pipiens, Cx. restuans, and Cx. salinarius have been implicated as the principal vectors because they are physiologically competent (5), frequently infected with the virus in nature, and closely associated with WNV transmission foci (6). However, the precise role that each of these species plays in enzootic transmission among birds or epidemic transmission to humans is not entirely clear.
# link: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3291451/
